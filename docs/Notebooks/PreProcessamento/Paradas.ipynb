# %%
# Istalando pacotes necessários
# %pip install geopandas matplotlib contextily shapely
# Out:
# Requirement already satisfied: geopandas in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (3.7.1)
# Requirement already satisfied: contextily in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: shapely in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyproj>=3.0.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: geopy in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from contextily) (2.3.0)
# Requirement already satisfied: mercantile in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: rasterio in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from contextily) (1.3.8)
# Requirement already satisfied: requests in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from contextily) (2.31.0)
# Requirement already satisfied: joblib in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from contextily) (1.3.1)
# Requirement already satisfied: xyzservices in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from contextily) (2023.7.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas) (8.1.6)
# Requirement already satisfied: click-plugins>=1.0 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: affine in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: setuptools in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from rasterio->contextily) (65.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from requests->contextily) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages (from requests->contextily) (1.26.16)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as cx
from shapely.geometry import box, Point, Polygon, MultiPolygon
from shapely.wkt import loads

# %%
# lendo o arquivo .shp
caminho_shp = '../../databases/paradas/paradas.shp'
df = gpd.read_file(caminho_shp)

# %%
# pegando algumas informações
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5457 entries, 0 to 5456
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   parada      5457 non-null   object
#  1   descricao   5456 non-null   object
#  2   situacao    5457 non-null   object
#  3   estrutura_  4948 non-null   object
#  4   tipo        5455 non-null   object
#  5   geometry    5457 non-null   geometry
# dtypes: geometry(1), object(5)
# memory usage: 255.9+ KB

# %%
# O que temos na coluna 'geometry' ?
df['geometry']
# Out:
# 0       POINT (203628.051 8238910.255)
# 1       POINT (203626.569 8238879.548)
# 2       POINT (203515.071 8238613.416)
# 3       POINT (203481.047 8238551.784)
# 4       POINT (203579.703 8239213.734)
#                      ...
# 5452    POINT (167354.394 8264495.757)
# 5453    POINT (167311.355 8264500.454)
# 5454    POINT (163265.979 8265332.396)
# 5455    POINT (162912.871 8269061.030)
# 5456    POINT (163217.911 8264159.565)
# Name: geometry, Length: 5457, dtype: geometry

# %%
# Qual sistemas estamos?
# acessando o atributo crs
df.crs
# Out:
# <Projected CRS: EPSG:31983>
# Name: SIRGAS 2000 / UTM zone 23S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Brazil - between 48°W and 42°W, northern and southern hemispheres, onshore and offshore.
# - bounds: (-48.0, -33.5, -42.0, 5.13)
# Coordinate Operation:
# - name: UTM zone 23S
# - method: Transverse Mercator
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# O folium trabalha no sistema WGS 84(EPSG:4326), o correto é converter para esse formato
df = df.to_crs('EPSG:4326')

# %%
# Agora conseguimos plotar

# Pegando uma cordenada pelo indice
x = df.geometry.x.iloc[0] # longitude
y = df.geometry.y.iloc[0] # latitute
print(f'Coordenada x é longitude e vale: {x}\nCoordena y é latitude e vale: {y}')
# Out:
# Coordenada x é longitude e vale: -47.76791017881488
# Coordena y é latitude e vale: -15.911319542624627

# %%
import folium

# Criar um mapa Folium centrado nas coordenadas do ponto selecionado
mapa = folium.Map(location=[y, x], zoom_start=12)

# Adicionar um marcador para o ponto no mapa
folium.Marker(location=[y, x]).add_to(mapa)

# Exibir o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42d553326deb96624c9d8a3b319e7861 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42d553326deb96624c9d8a3b319e7861&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42d553326deb96624c9d8a3b319e7861 = L.map(
#                 &quot;map_42d553326deb96624c9d8a3b319e7861&quot;,
#                 {
#                     center: [-15.911319542624627, -47.76791017881488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b1c9d5126ad8aea1bb3e3ba36c594ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42d553326deb96624c9d8a3b319e7861);
#
#
#             var marker_7ac289217d4c141b8e1a13d22526e89b = L.marker(
#                 [-15.911319542624627, -47.76791017881488],
#                 {}
#             ).addTo(map_42d553326deb96624c9d8a3b319e7861);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# verificando se faz sentido o plot
df['descricao'].iloc[0]
# Out:
# 'Avenida Morro da Cruz'

# %%
# Lendo o arquivo das linhas
file = '../../databases/linhas/Linhas.shp'
linhas = gpd.read_file(file)
linhas.head(5)
linhas.linha.shape[0]
# Out:
# 1308

# %%
linestringRecanto = linhas[linhas['linha']=='0.813']
linestringRecantoIda = linestringRecanto.iloc[1] # ida
linestringRecantoVolta = linestringRecanto.iloc[0] # volta

# %%
import folium
from shapely.geometry import LineString

# Criar o objeto Linestring
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')

# Criar um mapa inicial
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

# Obter o objeto LineString a partir da coluna "geometry" do DataFrame
linestring1 = linestringRecanto.geometry.iloc[1] # Ida
linestring2 = linestringRecanto.geometry.iloc[0] # Volta

# Converter as coordenadas do Linestring para o formato que o Folium espera (latitude, longitude)
lat_lon_coordsIda = [(lat1, lon1) for lon1, lat1 in linestring1.coords]
lat_lon_coordsVolta = [(lat2, lon2) for lon2, lat2 in linestring2.coords]


# Adicionar o Linestring ao mapa como uma polilinha (linha poligonal)

# Plotando a ida
folium.PolyLine(locations=lat_lon_coordsIda, color='blue', tooltip=linestringRecanto['linha'].iloc[1]+ ' ' + linestringRecanto['sentido'].iloc[1]).add_to(m)

# Plotando a volta
folium.PolyLine(locations=lat_lon_coordsVolta, color='red', tooltip=linestringRecanto['linha'].iloc[0]+ ' ' + linestringRecanto['sentido'].iloc[0]).add_to(m)

# Mostrar o mapa
m.save('mapaLinestring.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be898a96043c14c2c6b12e356f368ef2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be898a96043c14c2c6b12e356f368ef2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be898a96043c14c2c6b12e356f368ef2 = L.map(
#                 &quot;map_be898a96043c14c2c6b12e356f368ef2&quot;,
#                 {
#                     center: [-15.7605, -47.78134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f1b259bed28c323dafe9dfe143a9c17 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_be898a96043c14c2c6b12e356f368ef2);
#
#
#             var poly_line_159568b147aa5e29a34e9724150ae676 = L.polyline(
#                 [[-15.933102266916315, -48.10891754199306], [-15.933185998136672, -48.108807991238685], [-15.93340999523403, -48.108525495088145], [-15.933419523786512, -48.10849607013923], [-15.933419959958936, -48.10846583300539], [-15.933400571090756, -48.10841243949764], [-15.933305764283789, -48.108312854282865], [-15.933273562383947, -48.10830244488579], [-15.933243403196407, -48.10829693958246], [-15.933220235717016, -48.10830263140659], [-15.93319534110125, -48.108315353512296], [-15.932700948146334, -48.10895831300553], [-15.93244584156172, -48.10928197251519], [-15.932424904573713, -48.10928472361605], [-15.93240834520544, -48.10928312425452], [-15.932380701672058, -48.10927228097145], [-15.932011948441897, -48.10873397427042], [-15.9319625077659, -48.1087127140331], [-15.93191012725656, -48.108714931329196], [-15.931868362720541, -48.10872504111831], [-15.931834666028479, -48.1087639420912], [-15.931817167792971, -48.108823842662865], [-15.93224759865376, -48.109460764766446], [-15.932321336402978, -48.10959571923842], [-15.932344136311603, -48.10968349132112], [-15.932367098872463, -48.10980940054195], [-15.932362568692431, -48.10994307490539], [-15.932332517852501, -48.11008778122817], [-15.932263448418889, -48.11023255807511], [-15.93209405341763, -48.11047996059222], [-15.931919835284383, -48.11070107721031], [-15.93164789365474, -48.11106270696772], [-15.931610964986419, -48.11109401754556], [-15.931574144423534, -48.111099498503286], [-15.931544642856275, -48.11110475627459], [-15.931483116669263, -48.11109859898729], [-15.931430758331183, -48.11109995995848], [-15.931371718561225, -48.11111233911027], [-15.931314214428127, -48.11108658559446], [-15.931269858707546, -48.11105095367196], [-15.930189570128569, -48.110025346991186], [-15.929577608801964, -48.10944196575682], [-15.928258037828765, -48.10818838831729], [-15.927937294253818, -48.10788303427563], [-15.927807778842629, -48.10776257301313], [-15.927210362084208, -48.10719977473577], [-15.926851237016852, -48.106850148913], [-15.926316459959788, -48.10637012890984], [-15.926169384872782, -48.10624063970011], [-15.925699120415898, -48.10584314095591], [-15.92525405323611, -48.10549937884536], [-15.924633154958842, -48.10503975958355], [-15.92395940611415, -48.1045912156602], [-15.923597558362033, -48.104362528563165], [-15.923343469062997, -48.104214801694184], [-15.92323780194924, -48.10414664355253], [-15.92319567549768, -48.10409155944784], [-15.923160069885034, -48.104035231519724], [-15.923109431305207, -48.103939021310445], [-15.92307430063913, -48.103872283901616], [-15.923025215874963, -48.10380365184531], [-15.92297204641075, -48.10374772603555], [-15.922885035416126, -48.10368950153665], [-15.922772894873813, -48.103638245467074], [-15.922690773798758, -48.10361754051622], [-15.922600893039867, -48.103606900456164], [-15.92250622087745, -48.10361794380703], [-15.922447029236828, -48.10362809402743], [-15.922376056345888, -48.10363439553978], [-15.92231755238569, -48.10363282412056], [-15.922270905887581, -48.10362068217038], [-15.922191459484145, -48.10358317013326], [-15.92137248006535, -48.10314920666675], [-15.920771956285819, -48.102831171896646], [-15.920291771589174, -48.1025784965517], [-15.919486956621927, -48.1021541685875], [-15.918420606179355, -48.10160217223159], [-15.918236877854712, -48.10149048016219], [-15.918079902974803, -48.10139832132596], [-15.91799305090816, -48.10132981466096], [-15.917593551639234, -48.10102831954673], [-15.91740140651629, -48.1008687847479], [-15.91727878235172, -48.100758704211934], [-15.91701458934576, -48.10049927468045], [-15.916837677258178, -48.10032048571828], [-15.916482445936925, -48.099970279520946], [-15.916257154646464, -48.099718841476964], [-15.915045130008883, -48.098351814272284], [-15.91492382183887, -48.098217899751674], [-15.913771142545345, -48.09690623443199], [-15.91356507143006, -48.096674586537624], [-15.913440937405515, -48.096533574419475], [-15.913153510848991, -48.0962160052 ...

# %%
# Visualizando os rótulos  do dataframe das paradas
paradas = gpd.read_file("../../databases/paradas/paradas.shp")
paradas.tail(5)
# Out:
#      parada                                          descricao situacao  \
# 5452   1163  NUCLEO RURAL RODEADOR - LADO OPOSTO ESCOLA ROD...    ATIVA
# 5453   1164  NUCLEO RURAL RODEADOR - EM FRENTE ESCOLA RODEA...    ATIVA
# 5454   1166  ANTES DA ENTRADA PARA A DF 445 NORTE - KM 7 DF...    ATIVA
# 5455   1159  LADO OPOSTO A ENTRADA DA RADIOBRAS E DF 220 DF...    ATIVA
# 5456   6374  Km 07 - Gleba 02 - Chácara 116 - Chácara Beatr...    ATIVA
#
#                estrutura_      tipo                        geometry
# 5452  ACOSTAMENTO OU BAIA    Tipo C  POINT (167354.394 8264495.757)
# 5453  ACOSTAMENTO OU BAIA    Tipo C  POINT (167311.355 8264500.454)
# 5454        SEM ESTRUTURA    Tipo C  POINT (163265.979 8265332.396)
# 5455        SEM ESTRUTURA  Habitual  POINT (162912.871 8269061.030)
# 5456        SEM ESTRUTURA    Padrão  POINT (163217.911 8264159.565)

# %%
# convertendo para o sistema adequado
paradas = paradas.to_crs('EPSG:4326')
paradas
# Out:
#      parada                                          descricao    situacao  \
# 0      6710                              Avenida Morro da Cruz  DESATIVADA
# 1      6711                              Avenida Morro da Cruz  DESATIVADA
# 2      6712                              Avenida Morro da Cruz  DESATIVADA
# 3      6713                              Avenida Morro da Cruz  DESATIVADA
# 4      6827                                Residencial Vitoria  DESATIVADA
# ...     ...                                                ...         ...
# 5452   1163  NUCLEO RURAL RODEADOR - LADO OPOSTO ESCOLA ROD...       ATIVA
# 5453   1164  NUCLEO RURAL RODEADOR - EM FRENTE ESCOLA RODEA...       ATIVA
# 5454   1166  ANTES DA ENTRADA PARA A DF 445 NORTE - KM 7 DF...       ATIVA
# 5455   1159  LADO OPOSTO A ENTRADA DA RADIOBRAS E DF 220 DF...       ATIVA
# 5456   6374  Km 07 - Gleba 02 - Chácara 116 - Chácara Beatr...       ATIVA
#
#                estrutura_      tipo                     geometry
# 0           SEM ESTRUTURA  Habitual  POINT (-47.76791 -15.91132)
# 1           SEM ESTRUTURA  Habitual  POINT (-47.76793 -15.91160)
# 2           SEM ESTRUTURA  Habitual  POINT (-47.76900 -15.91399)
# 3           SEM ESTRUTURA  Habitual  POINT (-47.76933 -15.91454)
# 4           SEM ESTRUTURA  Habitual  POINT (-47.76832 -15.90857)
# ...                   ...       ...                          ...
# 5452  ACOSTAMENTO OU BAIA    Tipo C  POINT (-48.10282 -15.67575)
# 5453  ACOSTAMENTO OU BAIA    Tipo C  POINT (-48.10322 -15.67570)
# 5454        SEM ESTRUTURA    Tipo C  POINT (-48.14080 -15.66765)
# 5455        SEM ESTRUTURA  Habitual  POINT (-48.14358 -15.63395)
# 5456        SEM ESTRUTURA    Padrão  POINT (-48.14141 -15.67823)
#
# [5457 rows x 6 columns]

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium

# Criar o objeto Linestring
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')

# Obter o objeto LineString a partir da coluna "geometry" do DataFrame
linestring = linestringRecanto.geometry.iloc[0]

# Lista para armazenar as paradas encontradas
paradas_encontradas = []

# Conjunto para armazenar os números das paradas encontradas
numeros_paradas_encontradas = set()

# Função para aproximar as coordenadas para 2 casas decimais
def aproximar_coordenadas(coord):
    return round(coord, 2)

# Iterar sobre os pontos de paradas e verificar se estão contidos na Linestring
for idx, ponto_parada in paradas.iterrows():
    numero_parada = ponto_parada["parada"]
    ponto = ponto_parada["geometry"]
    ponto_aproximado = Point(aproximar_coordenadas(ponto.x), aproximar_coordenadas(ponto.y))
    linestring_aproximada = LineString([Point(aproximar_coordenadas(x), aproximar_coordenadas(y)) for x, y in linestring.coords])
    if linestring_aproximada.contains(ponto_aproximado) and numero_parada not in numeros_paradas_encontradas:
        paradas_encontradas.append(ponto_parada)
        numeros_paradas_encontradas.add(numero_parada)

# Criar um novo GeoDataFrame com as paradas encontradas
gdf_paradas_encontradas = gpd.GeoDataFrame(paradas_encontradas, crs='EPSG:4326')
display(gdf_paradas_encontradas)
# Plotar as paradas de ônibus no mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

for idx, ponto_parada in gdf_paradas_encontradas.iterrows():
    lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
    folium.Marker([lat, lon], popup=ponto_parada['descricao']).add_to(m)

# Mostrar o mapa com as paradas de ônibus
m.save('mapa_paradas_onibus.html')
# Out:
#      parada                                      descricao situacao  \
# 69     3517                           EQN 513/514 W3 NORTE    ATIVA
# 70     3473                           SQN 113 EIXO W NORTE    ATIVA
# 119    2649                                   BL. 300 NB 1    ATIVA
# 120    2672                      EM FRENTE AO BL. 211 NB 1    ATIVA
# 121    6057                    FRENTE A RODA DO CHOPP EPNB    ATIVA
# ...     ...                                            ...      ...
# 5292   3291         EQS 106/107 - Cine Brasília Eixo W Sul    ATIVA
# 5293   3343         EQS 106/107 - Cine Brasília Eixo W Sul    ATIVA
# 5300   3383         EQS 106/107 - CINE BRASILIA EIXO W SUL    ATIVA
# 5353   4723  APOS O VIADUTO DE ACESSO AO LAGO NORTE BR-020    ATIVA
# 5354   4583                            APOS VIADUTO DF-007    ATIVA
#
#                estrutura_            tipo                     geometry
# 69    ACOSTAMENTO OU BAIA     Tradicional  POINT (-47.89601 -15.74749)
# 70    ACOSTAMENTO OU BAIA     Tradicional  POINT (-47.88979 -15.74707)
# 119         SEM ESTRUTURA           Placa  POINT (-47.96304 -15.86636)
# 120   ACOSTAMENTO OU BAIA          Cemusa  POINT (-47.96287 -15.86609)
# 121   ACOSTAMENTO OU BAIA          Tipo C  POINT (-47.96680 -15.86686)
# ...                   ...             ...                          ...
# 5292  ACOSTAMENTO OU BAIA          Cemusa  POINT (-47.89929 -15.81486)
# 5293  ACOSTAMENTO OU BAIA          Cemusa  POINT (-47.89912 -15.81473)
# 5300  ACOSTAMENTO OU BAIA  Fibra de Vidro  POINT (-47.89896 -15.81460)
# 5353        SEM ESTRUTURA          Tipo C  POINT (-47.89611 -15.72536)
# 5354  ACOSTAMENTO OU BAIA          Tipo C  POINT (-47.89579 -15.72520)
#
# [400 rows x 6 columns]

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium

# Criar o objeto Linestring
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')

# Obter o objeto LineString a partir da coluna "geometry" do DataFrame
linestring = linestringRecanto.geometry.iloc[0]

# Lista para armazenar as paradas encontradas
paradas_encontradas = []

# Função para aproximar as coordenadas para 2 casas decimais

#def aproximar_coordenadas(coord):
#    return round(coord, )

# Definir o limite de proximidade aceitável (em graus)
limite_proximidade = 0.0002

#Iterar sobre os pontos de paradas e verificar se estão próximos da Linestring
for idx, ponto_parada in paradas.iterrows():
    ponto = ponto_parada["geometry"]
    distancia = linestring.distance(ponto)
    if distancia <= limite_proximidade:
        paradas_encontradas.append(ponto_parada)


# Criar um novo GeoDataFrame com as paradas encontradas
#gdf_paradas_encontradas = gpd.GeoDataFrame(paradas_encontradas, crs='EPSG:4326')

display(gdf_paradas_encontradas)
# Plotar as paradas de ônibus no mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

for idx, ponto_parada in gdf_paradas_encontradas.iterrows():
    lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
    folium.Marker([lat, lon], popup=ponto_parada['parada']).add_to(m)

# Mostrar o mapa com as paradas de ônibus
m.save('mapa_paradas_onibus.html')
m
# Out:
#      parada                                       descricao situacao  \
# 69     3517                            EQN 513/514 W3 NORTE    ATIVA
# 122    6058                        FRENTE AO BLOCO 440 EPNB    ATIVA
# 123    6059                         FRENTE AO BLOCO 91 EPNB    ATIVA
# 226    4027  QN 01 CONJ. 16 CASA 13 APOS A PASSARELA DF 075    ATIVA
# 227    4028                   QN 01 CONJ. 31 CASA 24 DF 075    ATIVA
# ...     ...                                             ...      ...
# 5211   3572       ENTREQUADRA 509/508 - HOSPITAL DIA W3 SUL    ATIVA
# 5243   3470           LATERAL HOSPITAL SANTA HELENA LIGACAO    ATIVA
# 5249   3520           EM FRENTE JUSTICA DO TRABALHO LIGACAO    ATIVA
# 5255   3519                      EQN 515/516 - BRB W3 NORTE    ATIVA
# 5271   3518                  EQN 514/515 - HYUNDAI W3 NORTE    ATIVA
#
#                estrutura_         tipo                     geometry
# 69    ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89601 -15.74749)
# 122   ACOSTAMENTO OU BAIA       Tipo C  POINT (-47.96505 -15.86656)
# 123   ACOSTAMENTO OU BAIA       Tipo C  POINT (-47.96109 -15.86449)
# 226   ACOSTAMENTO OU BAIA       Tipo C  POINT (-48.00549 -15.87796)
# 227   ACOSTAMENTO OU BAIA       Tipo C  POINT (-48.00207 -15.87766)
# ...                   ...          ...                          ...
# 5211  ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.90791 -15.81387)
# 5243        SEM ESTRUTURA       Tipo C  POINT (-47.89732 -15.73542)
# 5249        SEM ESTRUTURA       Cemusa  POINT (-47.89838 -15.73702)
# 5255  ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89805 -15.74110)
# 5271  ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89692 -15.74462)
#
# [99 rows x 6 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b258e99a1ef3bfbd0fbb80d1388cb50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b258e99a1ef3bfbd0fbb80d1388cb50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b258e99a1ef3bfbd0fbb80d1388cb50 = L.map(
#                 &quot;map_4b258e99a1ef3bfbd0fbb80d1388cb50&quot;,
#                 {
#                     center: [-15.7605, -47.78134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5840ca8a57ae0ff165617fd778fe0eea = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4b258e99a1ef3bfbd0fbb80d1388cb50);
#
#
#             var marker_286669f172fb2f151d3d5ce99c5fb0f8 = L.marker(
#                 [-15.747487243955707, -47.89600866323914],
#                 {}
#             ).addTo(map_4b258e99a1ef3bfbd0fbb80d1388cb50);
#
#
#         var popup_bb9b5556d47a0fef03b03c16908d8bd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4331b0293e1340c50da5acffbf54e802 = $(`&lt;div id=&quot;html_4331b0293e1340c50da5acffbf54e802&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3517&lt;/div&gt;`)[0];
#                 popup_bb9b5556d47a0fef03b03c16908d8bd6.setContent(html_4331b0293e1340c50da5acffbf54e802);
#
#
#
#         marker_286669f172fb2f151d3d5ce99c5fb0f8.bindPopup(popup_bb9b5556d47a0fef03b03c16908d8bd6)
#         ;
#
#
#
#
#             var marker_face4a3438230c06c57b59e5c4b62695 = L.marker(
#                 [-15.866555379423424, -47.96504713913905],
#                 {}
#             ).addTo(map_4b258e99a1ef3bfbd0fbb80d1388cb50);
#
#
#         var popup_f8968d8253394047c422c051cc63063c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31bcff21e341a5bf069615572e586ee3 = $(`&lt;div id=&quot;html_31bcff21e341a5bf069615572e586ee3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6058&lt;/div&gt;`)[0];
#                 popup_f8968d8253394047c422c051cc63063c.setContent(html_31bcff21e341a5bf069615572e586ee3);
#
#
#
#         marker_face4a3438230c06c57b59e5c4b62695.bindPopup(popup_f8968d8253394047c422c051cc63063c)
#         ;
#
#
#
#
#             var marker_6d3de70be36c0e4fbe2b82b2d22e2710 = L.marker(
#                 [-15.864490388747809, -47.96108520646956],
#                 {}
#             ).addTo(map_4b258e99a1ef3bfbd0fbb80d1388cb50);
#
#
#         var popup_bf0db83362e5cc45f6e9092347cb6028 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca7b89f2b64ecd1f2446d91f75270794 = $(`&lt;div id=&quot;html_ca7b89f2b64ecd1f2446d91f75270794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6059&lt;/div&gt;`)[0];
#                 popup_bf0db83362e5cc45f6e9092347cb6028.setContent(html_ca7b89f2b64ecd1f2446d91f75270794);
#
#
#
#         marker_6d3de70be36c0e4fbe2b82b2d22e2710.bindPopup(popup_bf0db83362e5cc45f6e9092347cb6028)
#         ;
#
#
#
#
#             var marker_b03ff9af3ad77d3a55eef56767d998c7 = L.marker(
#                 [-15.877962420610736, -48.00549404760407],
#                 {}
#             ).addTo(map_4b258e99a1ef3bfbd0fbb80d1388cb50);
#
#
#         var popup_3c1a8867439874028cccb20d94535ec8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b47f130afd241742e69d1cbc154fa30 = $(`&lt;div id=&quot;html_9b47f130afd241742e69d1cbc154fa30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4027&lt;/div&gt;`)[0];
#                 popup_3c1a8867439874028cccb20d94535ec8.setContent(html_9b47f130afd241742e69d1cbc154fa30);
#
#
#
#         marker_b03ff9af3ad77d3a55eef56767d998c7.bindPopup(popup_3c1a8867439874028cccb20d94535ec8)
#         ;
#
#
#
#
#             var marker_332659f99ab335c5391dd6f7b9a7eea3 = L.marker(
#                 [-15.877661139468985, -48.00206983803816],
#                 {}
#             ).addTo(map_4b258e99a1ef3bfbd0fbb80d1388cb50);
#
#
#         var popup_f893577b547c655f319906d4e4afcd09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_059549232938ee616500300dc0e271c0 = $(`&lt;div id=&quot;html_059549232938ee616500300dc0e271c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4028&lt;/div&gt;`)[0];
#                 popup_f893577b547c655f319906d4e4afcd09.setContent(html_059549232938ee616500300dc0e271c0);
#
#
#
#         marker_332659f99ab335c5391dd6f7b9a7eea3.bindPopup(popup_f893577b547c655f319906d4e4afcd09)
#         ;
#
#
#
#
#             var marker_1bd9d4ecfcbfafe55f0db6aa41a62f1b = L.marker(

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium

# Carregar a Linestring e o GeoDataFrame das paradas (linestringRecanto e paradas)

# Criar o objeto LineString
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')
linestring = linestringRecanto.geometry.iloc[0]

# Lista para armazenar as paradas encontradas
paradas_encontradas = []

# Definir o limite de proximidade aceitável (em metros)
limite_proximidade = 0.1  # 10 metros

# Coordenadas da Linestring
linha_coords = list(linestring.coords)

# Iterar sobre os pontos de paradas e verificar se estão próximos da Linestring
for idx, ponto_parada in paradas.iterrows():
    ponto_coords = (ponto_parada["geometry"].x, ponto_parada["geometry"].y)
    ponto = Point(ponto_coords)
    distancia = linestring.distance(ponto)
    print(distancia)
    if distancia <= limite_proximidade:
        paradas_encontradas.append(ponto_parada)

# Plotar as paradas de ônibus no mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

for ponto_parada in paradas_encontradas:
    lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
    folium.Marker([lat, lon], popup=ponto_parada['parada']).add_to(m)

# Mostrar o mapa com as paradas de ônibus
# Out:
# 0.16774646938927223
# 0.1679148476835381
# 0.16868551843414936
# 0.168809167209282
# 0.165644605767679
# 0.15490370805505352
# 0.0746279484389768
# 0.07495826092042937
# 0.0784201001713482
# 0.08448575692977929
# 0.08799269454702617
# 0.08838576825701475
# 0.08420394051538092
# 0.07928502092985047
# 0.17907409454601372
# 0.17932718909163653
# 0.17907409454601372
# 0.17006852384522064
# 0.17018353285482293
# 0.17109842538757797
# 0.17015750881229086
# 0.17114172391318522
# 0.1790589548488338
# 0.1791176007996427
# 0.16944129982571668
# 0.16956790888386256
# 0.1596926301286097
# 0.26453591448037694
# 0.2574437569130193
# 0.2608685131205368
# 0.2607812966695465
# 0.26076323585694194
# 0.2625455962906113
# 0.25731493392935384
# 0.2605239060489298
# 0.26062935098458434
# 0.2605909362817526
# 0.2606845066814151
# 0.2618751676036004
# 0.26914472706698883
# 0.26675818497701137
# 0.2658165230902594
# 0.26734429829005574
# 0.26878191679237223
# 0.2685403326654604
# 0.2663635304098236
# 0.2645016696790325
# 0.12993293309689521
# 0.14481347648856652
# 0.13636331069994354
# 0.1425600351427152
# 0.1384748592614308
# 0.1289046454916487
# 0.14528212773941196
# 0.13832360035431635
# 0.13243213347099875
# 0.1425768990392595
# 0.13606975151219128
# 0.13246592501981494
# 0.19804638041377257
# 0.20141005160268222
# 0.22728721796564985
# 0.22717364671214463
# 0.22837875430445104
# 0.22864862933742863
# 0.2255427912814935
# 0.2256425118317189
# 0.226261454975197
# 0.22615521351160747
# 0.0002945589000260857
# 0.006344813641294489
# 0.2254472740132514
# 0.22870929905412468
# 0.22858570239315418
# 0.2255879517611516
# 0.032945191451052805
# 0.023752359949531447
# 0.02353303747251969
# 0.17555343008049185
# 0.16346854135926198
# 0.1680866497031566
# 0.1677416610472377
# 0.17513529341126385
# 0.16384183068402522
# 0.2547777674948698
# 0.25201049042603074
# 0.2548478293126447
# 0.2519508985550684
# 0.1009289496338412
# 0.10556027649354693
# 0.10606592620666858
# 0.09915187481416275
# 0.10278439648332015
# 0.10585880780285889
# 0.09923877826775719
# 0.10293777760367438
# 0.1006797829230347
# 0.09877222838703807
# 0.02988433804573532
# 0.029331809054128292
# 0.028985258329405364
# 0.02952942471850372
# 0.0290682729158949
# 0.02914602851897971
# 0.029427710161248854
# 0.029569492253695918
# 0.029846095570944347
# 0.03029067420281303
# 0.03506281991826074
# 0.033027905588580916
# 0.02983148952591061
# 0.039586189508553596
# 0.04178645225284374
# 0.04090214857701515
# 0.04196959792068642
# 0.04024769130062179
# 0.04104008918056349
# 0.04141305418450037
# 0.04358699290263039
# 0.04965679572178543
# 0.04933662988431212
# 0.05254871452006418
# 0.0511322481046103
# 0.04695981663354294
# 0.04187045990132393
# 0.03836151952340514
# 0.03823703492503323
# 0.03875426915114237
# 0.035187939508778104
# 0.038588152102630086
# 0.04074521715894096
# 0.16667765274419524
# 0.17049884783318647
# 0.17154130665116224
# 0.17068719331022125
# 0.17097559369581275
# 0.1695359837061054
# 0.17116746395499433
# 0.09289416815226839
# 0.09564179359904297
# 0.09013891093159017
# 0.08817105346683105
# 0.08983608551951326
# 0.08693271900996737
# 0.13649417795349236
# 0.13719940720063534
# 0.13177077691192104
# 0.13197654624829847
# 0.1529611155413212
# 0.15071471136878958
# 0.15571113839171938
# 0.14629047334471765
# 0.15640928544519608
# 0.1547442389918247
# 0.15134731043443805
# 0.15398298261379395
# 0.1590566371077893
# 0.1560446607052736
# 0.14740072366360035
# 0.1512698018789513
# 0.15145531052893887
# 0.15186896889516496
# 0.1633113534032223
# 0.1488204274519856
# 0.1539854115747202
# 0.039865924863290624
# 0.04078236518995092
# 0.041427210529486065
# 0.041861564666934206
# 0.03987453654618679
# 0.040320357361142915
# 0.03943664301093892
# 0.057074674481597795
# 0.05708557363817572
# 0.03743129260662188
# 0.03539129244986304
# 0.03742847870665438
# 0.034019994248043625
# 0.034805661094934846
# 0.035814525498527816
# 0.03355668328389171
# 0.034277326253215404
# 0.04014244211798421
# 0.03994153225555732
# 0.07042688594782871
# 0.0682467576314021
# 0.06924333756004986
# 0.06832285915504978
# 0.07029461016272665
# 0.06891672337992308
# 0.06842430288701828
# 0.12167122705003991
# 0.12806120389111322
# 0.1282740259402135
# 0.12839626074490984
# 0.1286687239070065
# 0.12219071939711558
# 0.12162600096019946
# 0.12132691094724557
# 0.12246907050508087
# 0.1211768557361518
# 0.12150497716989493
# 0.12201079187551508
# 0.09069123322063781
# 0.09070156584973091
# 0.09229466096653595
# 0.13037150194537062
# 0.12804274985574088
# 0.1297142874292063
# 0.12812689862883866
# 0.1382153003798743
# 0.14016832604261223
# 0.1375962996799216
# 0.1377554113265597
# 0.024736889144448205
# 0.01577656170705793
# 0.02137751522443627
# 0.01776309229701782
# 0.01926403946087108
# 0.021552112747288438
# 0.02667559140968927
# 0.01605480449412109
# 0.01787353889062265
# 0.02644461564379057
# 0.023668183358329632
# 0.023797018016485323
# 0.02334594829802802
# 0.026715718829006252
# 0.02848753768492026
# 0.02653953157446588
# 0.024119140831658236
# 0.030952514688443535
# 0.029466013586155037
# 0.02612415396976547
# 0.023234989010524225
# 0.07159589925542942
# 0.07132359812904465
# 0.07184312494437536
# 0.07156102219315699
# 0.07117036300291829
# 0.07156412633860938
# 0.07534619829951383
# 0.07468829163173699
# 0.07288080827586059
# 0.07432145163859431
# 0.07386869058997575
# 0.07815246329916146
# 0.07831163924935058
# 0.0737884420565313
# 0.07453284435132387
# 0.07533405392733022
# 0.07609648690441882
# 0.07875254868686427
# 0.07653832875058264
# 0.07809527108644375
# 0.00952357527111796
# 0.010419004000735055
# 0.01344976521962504
# 0.016325597880648992
# 0.008455279385226493
# 0.008224800298600926
# 0.010592015519110758
# 0.009306174507479033
# 0.01082610766130705
# 0.008390585533149494
# 0.008772645212774073
# 0.0096816907134742
# 0.027169014933456026
# 0.025908828837172704
# 0.025395008317604117
# 0.04393694862930764
# 0.04671044236297972
# 0.04400616478933024
# 0.04376728365711034
# 0.04693603909205313
# 0.12997539146572426
# 0.13574534606059463
# 0.13663267300878362
# 0.13438944460350902
# 0.13212275841789883
# 0.1344641112805832
# 0.13239561744860256
# 0.13087162183042772
# 0.1293918721727902
# 0.13286571662933847
# 0.13245200363413184
# 0.10877999917862173
# 0.09286877864336872
# 0.12332860247551455
# 0.12804280923333083
# 0.08999805607398406
# 0.12798756719931415
# 0.09010920986356959
# 0.10873335080720498
# 0.1819232137100516
# 0.18303320746614232
# 0.1746601667771901
# 0.1822494749029932
# 0.17500362619798324
# 0.08321764645621862
# 0.08981966197013955
# 0.08602553483981398
# 0.08285697716582476
# 0.08228484517732217
# 0.0823951822418066
# 0.08204360416712891
# 0.08473138158082892
# 0.0835752839957489
# 0.08451865742638796
# 0.08738259598859809
# 0.08937242745312347
# 0.08608118775393087
# 0.0831306547615621
# 0.09102060198778304
# 0.08868616206589987
# 0.09001003864500792
# 0.08889915876894303
# 0.09052083735720605
# 0.09068884575167546
# 0.08870878683706815
# 0.09194988517583233
# 0.08092408194173645
# 0.0807373727140666
# 0.011474884805493
# 0.011238904291614513
# 0.012274810774730124
# 0.012889244334026296
# 0.011914113901995475
# 0.011565337724632033
# 0.012670905688688477
# 0.05466856509385574
# 0.05149019953642314
# 0.05408017690379609
# 0.05661058084598045
# 0.05607670439065022
# 0.0559763572325623
# 0.054468853126012996
# 0.055971387831153796
# 0.05072166149006195
# 0.05061607614487287
# 0.05615636871132763
# 0.05621225552231588
# 0.052756593980357376
# 0.05038121251133082
# 0.07182480759715168
# 0.07225696534755316
# 0.06847219780189652
# 0.0704836674663481
# 0.06800549796375435
# 0.06813640241399883
# 0.08224693750217815
# 0.08230854839310074
# 0.09593030655901967
# 0.09390943094114564
# 0.09196458661716078
# 0.09372658231750147
# 0.09614914535759247
# 0.09240267678112152
# 0.09317332098837644
# 0.13731236775740194
# 0.1363161856200208
# 0.1369822107538675
# 0.1366621594304794
# 0.13660576059337415
# 0.09667557933422556
# 0.0823033117514836
# 0.06957047128842635
# 0.08896025811630626
# 0.06972620616142172
# 0.1012984500328874
# 0.10067312135268622
# 0.08240947731146064
# 0.08569250424449527
# 0.0890942492644537
# 0.08565199123793103
# 0.08275462288174097
# 0.08408713342630554
# 0.09660298076074866
# 0.24755478437774417
# 0.24194948604180236
# 0.23603348007071312
# 0.23366973771429006
# 0.23583736603021555
# 0.24769879340306242
# 0.24953279182278656
# 0.259161720966095
# 0.23342382958276203
# 0.24176820275151256
# 0.25802354613469464
# 0.24966738404357075
# 0.22854937299025305
# 0.23102490784753837
# 0.22576624358265102
# 0.22845978777373568
# 0.2348172901170256
# 0.2260116396889138
# 0.2316144881248484
# 0.23520310197213393
# 0.1530223738718271
# 0.15551294115376407
# 0.15496514568931377
# 0.10001047839945156
# 0.09811374307665136
# 0.09989110240864402
# 0.0982215440368292
# 0.08973767981864415
# 0.0882304282328367
# 0.12655951319993117
# 0.12413498262537064
# 0.12031402439210695
# 0.13017922914342517
# 0.12996767341730833
# 0.12628974470753868
# 0.119995856545322
# 0.11627489535959044
# 0.11675111954039258
# 0.057049223617753594
# 0.14916325235468514
# 0.15859245426596133
# 0.01861951465655729
# 0.01847238995318924
# 0.02181840751134041
# 0.02146208792989188
# 0.01898887600629858
# 0.02987021471666654
# 0.024817982695138466
# 0.024817982695138466
# 0.0270775344755485
# 0.030371710129032104
# 0.026426968203595115
# 0.02747800015089691
# 0.026768235419460842
# 0.02707537565345239
# 0.024818812090734707
# 0.026603594738960366
# 0.02643565913090297
# 0.02490611293063759
# 0.27488525843550987
# 0.27528158212361487
# 0.2748765558383778
# 0.12296094002897222
# 0.12301415885074832
# 0.12388103362477988
# 0.1245157146450218
# 0.16522573814536543
# 0.16845870056898085
# 0.168334798645364
# 0.16482123262984752
# 0.1646847284417982
# 0.1649092546319617
# 0.29120006900102285
# 0.28899472464372855
# 0.2957644138710523
# 0.29420450430393025
# 0.2992143986662432
# 0.2992870605591617
# 0.2889485917320992
# 0.29120551950338436
# 0.2940435770144993
# 0.0998512361273128
# 0.0995856586046747
# 0.09633601269676112
# 0.09789458402232057
# 0.09555136163873845
# 0.09662894594154561
# 0.09985663407802094
# 0.10011179886873264
# 0.10112000589507558
# 0.10150602629449333
# 0.2813026841550472
# 0.22386934473758752
# 0.28348353198312143
# 0.2836714505602418
# 0.22384816374923766
# 0.2813117718669189
# 0.024281470412142812
# 0.024678041182125358
# 0.02374693237810205
# 0.019744367360390046
# 0.024625917789476724
# 0.02570388138641708
# 0.024564841528578733
# 0.025323949386714527
# 0.025929382125416484
# 0.02172429490978738
# 0.021832991723232498
# 0.024179410372091367
# 0.04587132190171328
# 0.04590351913682654
# 0.04396288881767417
# 0.04315153567170062
# 0.0032755867760938463
# 0.0037176338422413384
# 0.003961715031271306
# 0.0042427839310329295
# 0.00399879302499764
# 0.003678101485103162
# 6.805641664475986e-05
# 6.205259807956825e-05
# 6.898943509753729e-05
# 9.335619067577474e-05
# 7.402375180906172e-05
# 0.00028773579260550506
# 0.00029289760521020815
# 0.0002914183192871331
# 0.0018224815549459132
# 0.13248546594069208
# 0.133789918229268
# 0.13679491876104935
# 0.13977064415154317
# 0.1327495562840655
# 0.13508800428372297
# 0.13690260117811348
# 0.13304282333905096
# 0.19742451487781731
# 0.21281753299257336
# 0.0857369399380972
# 0.08564551382121312
# 0.09017585172843617
# 0.08497372703129819
# 0.08865148951329556
# 0.013938621997372598
# 0.02223418224662847
# 0.013618674298204632
# 0.021947361448040104
# 0.013939568205406993
# 0.013608369353619434
# 0.010553481437799241
# 0.1064236281349507
# 0.10280343594685802
# 0.09614753096938258
# 0.10678868870058325
# 0.10259333050256836
# 0.09650382298901954
# 0.11019725244224395
# 0.09899655693703782
# 0.11024922489346692
# 0.039233821408341196
# 0.03875303210976135
# 0.03933047427716433
# 0.0392786154829833
# 0.03885094419571532
# 0.03924757453565135
# 0.03872746334145573
# 0.03878565355257447
# 0.0383415419889743
# 0.03877539184739578
# 0.03282873448903818
# 0.032916172559803863
# 0.03238158922907192
# 0.032910820861811976
# 0.03332478056921438
# 0.032389483079595674
# 0.03293945481879624
# 0.17935862475340011
# 0.16262239371310389
# 0.16203894604281552
# 0.17153597654252076
# 0.17324140657275483
# 0.17485080697942426
# 0.1724548577190994
# 0.17026795924377214
# 0.16906340587878543
# 0.16307550078235486
# 0.16263224631671377
# 0.1567036454606222
# 0.15611939093817212
# 0.15577098216642626
# 0.17627861513028398
# 0.1773939149992204
# 0.16899549040673864
# 0.17606069001792227
# 0.1591428897145618
# 0.09319519635824138
# 0.09263628116617548
# 0.09350028215786677
# 0.09111350011847509
# 0.09127705111521622
# 0.02113377877673822
# 0.018091037400404873
# 0.018537612856106632
# 0.0177286630504514
# 0.018649354061014277
# 0.018594891216110077
# 0.02012829443968351
# 0.019978557281812328
# 0.017325694619104732
# 0.018489545552231538
# 0.020641145995408557
# 0.018620119968493436
# 0.017227089518263558
# 0.08663705626449375
# 0.0866193550449323
# 0.07672181611893082
# 0.09128694893481615
# 0.09098488586907695
# 0.07658964713804048
# 0.07942190556785969
# 0.07963655296224395
# 0.09345662110746975
# 0.09915637117398507
# 0.09765389579964932
# 0.09794275060870702
# 0.11759617551994882
# 0.12111856568668017
# 0.12126090704243195
# 0.11870379037193823
# 0.12053714710950464
# 0.12058674888753729
# 0.11851144616328459
# 0.15815874938455043
# 0.15751985573162827
# 0.1586637577867753
# 0.16009927834400398
# 0.16029961491508016
# 0.1576666916878884
# 0.05363674519766493
# 0.04945126005469108
# 0.053780951701743254
# 0.04866125564237756
# 0.4673886420970081
# 0.4945631113750349
# 0.5058881117668853
# 0.4947609377413482
# 0.48338526049946634
# 0.4742735293091517
# 0.46752878771087264
# 0.4592581042464165
# 0.48332235079658925
# 0.50605178924135
# 0.47433722484369684
# 0.4593129491137493
# 0.09992792804310684
# 0.0994508832930332
# 0.09964591889088312
# 0.10006042367197632
# 0.11609504268672052
# 0.1048236782529086
# 0.11629010294014992
# 0.10243730384214403
# 0.10239559706981047
# 0.10219769667865271
# 0.10223732801440388
# 0.11154323213214799
# 0.11140449228437949
# 0.10652596620521636
# 0.1076066794294801
# 0.10802767599071542
# 0.10978779165423597
# 0.10975183327876777
# 0.10739098716086282
# 0.14952544629543965
# 0.1403960145757804
# 0.14050504051378185
# 0.14929336378438038
# 0.08520104680854743
# 0.08575258101387966
# 0.08897882164759241
# 0.08793071765350449
# 0.13079343682411707
# 0.1242909792782466
# 0.12441884031777019
# 0.1305302508380921
# 0.2360004158126968
# 0.24757322957212644
# 0.2668486342572791
# 0.2189298257948032
# 0.2291158499285817
# 0.20813083050735745
# 0.20820010276991532
# 0.20717354515275124
# 0.2060378423634773
# 0.12615346739785627
# 0.12227987869397493
# 0.12623532695849551
# 0.12262248933865696
# 0.12227658859895658
# 0.14291622718381963
# 0.13988733903681033
# 0.13988676667086333
# 0.1438509767592896
# 0.14515549428613142
# 0.14401826078006183
# 0.14397244632504846
# 0.14379218666006072
# 0.14391010776889446
# 0.1446300855697301
# 0.027121026722697648
# 0.027162908070027764
# 0.03338162018923014
# 0.03330732683289382
# 0.028244280458307056
# 0.02955690211601872
# 0.030883276317025973
# 0.03166665649050537
# 0.03157738221215481
# 0.034501613363685894
# 0.03410158700252032
# 0.035118872528271394
# 0.0342691101807746
# 6.771100935938977e-05
# 7.630066936625928e-05
# 0.002849672473326794
# 0.0033654192329977913
# 0.00029603065714512
# 6.90971305338309e-05
# 0.0002940969461251586
# 7.133167876186107e-05
# 0.0002967963046999404
# 0.05146492724232875
# 0.049387759381856196
# 0.04841418275823927
# 0.051020232133213106
# 0.050640167000882336
# 0.04802316421285934
# 0.053126173542678026
# 0.04985886902541271
# 0.05147014616502523
# 0.049388338990072216
# 0.051519430357520574
# 0.04397058017059721
# 0.04600609842286724
# 0.04168713764533915
# 0.041493963776965084
# 0.04386092716436128
# 0.04553211787896789
# 0.06664515538046531
# 0.05872134102112967
# 0.05105077636205239
# 0.05471557778693425
# 0.051328444431938604
# 0.05167405425977955
# 0.05473572615933456
# 0.06136293313163668
# 0.06674391426713039
# 0.06188318834921305
# 0.10344639446467568
# 0.10034374176421033
# 0.09800343605847381
# 0.09961380839002945
# 0.09769566198968242
# 0.09890372806192017
# 0.10071495320147336
# 0.09701678154887299
# 0.10321809189913438
# 0.10147790382488775
# 0.10032367162611952
# 0.10088574526657049
# 0.10533325195645268
# 0.12240637310801293
# 0.12281521147595648
# 0.1293003329091947
# 0.12886620245800903
# 0.12920647012598396
# 0.12959870114804303
# 0.1482019168951994
# 0.1618911470311643
# 0.16285451773890078
# 0.1603960381882285
# 0.14817259893601625
# 0.16186375453770765
# 0.16017929749619872
# 0.1600038328755292
# 0.16020849909549953
# 0.048166543094060085
# 0.048048963114364684
# 0.03249127768777869
# 0.029247579247203746
# 0.03122778577318374
# 0.026199818787912135
# 0.2724945990683893
# 0.2778350828819373
# 0.2770574889561734
# 0.27159472943269264
# 0.28565473875359654
# 0.025844000119749633
# 0.02484574417375995
# 0.030194302865382747
# 0.0373825210668372
# 0.035538439750716716
# 0.030273310240430288
# 0.0371122357735184
# 0.03134538378678157
# 0.03511636272938391
# 0.01360035494578913
# 0.013552045559837732
# 0.014026047809738451
# 0.01391770895982354
# 0.013579017125544341
# 0.013889821629930485
# 0.010603601867159812
# 0.013865119195527967
# 0.0514415150519562
# 0.051307592212338
# 0.052584413517264526
# 0.053952202806847836
# 0.048509181484480024
# 0.05197834851439571
# 0.05141657620703437
# 0.05267966087162249
# 0.05341498309714689
# 0.054032692511227054
# 0.022231797564740374
# 0.022464581666910028
# 0.022174678234868017
# 0.03420932072100071
# 0.03437310905204313
# 7.569393848846683e-05
# 6.112127165043205e-05
# 0.00031066722649968076
# 0.0003153078547981392
# 9.909097874904819e-05
# 9.909097874904819e-05
# 0.00010542402570679886
# 0.0003207580405468177
# 0.0003207580405468177
# 0.0003207580405468177
# 8.811510700865555e-05
# 0.00031813273261390037
# 0.03983820851910786
# 0.03772836214586541
# 0.03969608428086244
# 0.04015041565426145
# 0.03897295696000685
# 0.03957149545375693
# 0.04014557619370584
# 0.0377764918975276
# 0.034325838232393074
# 0.046899981654049745
# 0.04058367605152556
# 0.040340304960962456
# 0.04700962277430579
# 0.02944898601108654
# 0.02953452774941596
# 0.03181456707266054
# 0.03181456707266054
# 0.03255762283840153
# 0.02944898601108654
# 0.029797635866622246
# 0.03186901918880919
# 0.03184240393959959
# 0.029418063194462492
# 0.02982823129907512
# 0.0297507702892441
# 0.032008672018335904
# 0.006577279058319084
# 0.00928138739035354
# 0.0053600715744897285
# 0.005324842982455803
# 0.008219339745976467
# 0.005750487438238502
# 0.008191153724339527
# 0.005995468240217097
# 0.005180116677594819
# 0.0059296856536749706
# 0.00755552085791697
# 0.007846094745037932
# 0.09914016085481545
# 0.10317884309690606
# 0.09953477401877318
# 0.10036089743785535
# 0.10049319366335921
# 0.10363647491424309
# 0.1047398073046326
# 0.10695640962782459
# 0.10695661859420434
# 0.10458722291645507
# 0.10586869150396247
# 0.10553433066292572
# 0.10393186280972881
# 0.10354270174461068
# 0.10573275632208257
# 0.10603928543678115
# 0.28776916509536027
# 0.28689546229865864
# 0.28660782344827457
# 0.2796918501407348
# 0.28134634327862107
# 0.2826123941907617
# 0.2845067357388285
# 0.2861386612504013
# 0.28845269001502744
# 0.2867380453519258
# 0.28510506161719174
# 0.2835701024938953
# 0.28209981554937114
# 0.28050044268570085
# 0.13370981480666966
# 0.13389838895536518
# 0.1342144436712326
# 0.13382329027952197
# 0.13533998286450188
# 0.037682510106558716
# 0.03780345160174312
# 0.050527470675838515
# 0.04318900008680788
# 0.04619527322044059
# 0.045607598497693864
# 0.04663798497427095
# 0.0453564215235102
# 0.05039685321815148
# 0.039447885715936444
# 0.0004083328483810195
# 0.0017228530334140913
# 0.00011469955118077234
# 7.074975504669723e-05
# 9.371697735919898e-05
# 0.0006896153989113135
# 0.0007123821248132145
# 0.0004102649199570232
# 0.004515894851509528
# 0.001990629671919501
# 0.003284244273314837
# 0.004718144208226816
# 0.004938072185102226
# 4.270602074227684e-05
# 0.00011503721447702368
# 0.0003957760611608492
# 0.004886151447638265
# 0.004786569462155288
# 0.004689605686549602
# 0.008262272205559796
# 0.007445347078003567
# 7.022276557487921e-05
# 0.0003721242825769707
# 0.005375774767355763
# 0.00536682514851524
# 0.004015257483024567
# 0.005394914056333726
# 0.002287783314726082
# 0.0023266842819572777
# 0.003015916270920379
# 0.002985950242870277
# 0.0043387646889606665
# 0.12300532331183321
# 0.12436737805078302
# 0.12413515741220822
# 0.1260009542120561
# 0.12424437232435011
# 0.1256590637274886
# 0.12270130792101577
# 0.04624077968612314
# 0.04043360202823511
# 0.043666453862853324
# 0.040335456578789515
# 0.04357998574790651
# 0.045943310283154716
# 0.06372140552266012
# 0.061050353395567455
# 0.06364429020200385
# 0.06304878962294486
# 0.06529232414365439
# 0.06535441847513289
# 0.06638220360325955
# 0.05949856639070768
# 0.06177914887853387
# 0.06224737655126577
# 0.06184679358148592
# 0.061563217557935146
# 0.060113145342370986
# 0.05911938874451254
# 0.05811227627270869
# 0.06033629585632418
# 0.055733445004014406
# 0.06626873915150816
# 0.02304025164568413
# 0.023798869141036412
# 0.02306996705484786
# 0.00713428980050416
# 0.00536719549019944
# 0.01080040954210471
# 0.005803868423587688
# 0.007094834295554243
# 0.005377384662621406
# 0.0107331389387476
# 0.010717444093965755
# 0.002310757163041856
# 0.0021120180471115805
# 0.005824246596266136
# 0.006030393615138688
# 0.011334590375888048
# 0.011809131837302788
# 0.011052834842912017
# 0.010660578402575633
# 0.006616956363668064
# 0.00805488112310147
# 0.009542300611531393
# 0.008074716164249117
# 0.006029858712630276
# 0.011140764888105023
# 0.01226559015222258
# 0.00940183564431007
# 0.007488208694436067
# 0.04426172541841531
# 0.03712527919063646
# 0.040984539354490396
# 0.03388948061358988
# 0.0366673150057619
# 0.044401599378736924
# 0.0381853835764209
# 0.03846473819262782
# 0.0002905987371973502
# 7.053814175012716e-05
# 0.0002957565516530742
# 0.013145826269277681
# 0.01329932665994891
# 0.012439397458132101
# 0.014568661001581397
# 0.0148669277507618
# 0.014178503101499556
# 0.01712023434375405
# 0.01339453722243794
# 0.010314407617180112
# 0.017007662993596143
# 0.017115905053120876
# 0.017124380585496746
# 0.017115143837317714
# 0.01684753749922418
# 0.01341856453982557
# 0.010527477926930793
# 0.015091611191086391
# 0.011921058565844257
# 0.011516518324357045
# 0.004955670429918279
# 0.0006979406767715857
# 6.682701224149244e-05
# 0.0007384010386453443
# 0.0007120437990670504
# 9.792688553407219e-05
# 0.0050787950872302244
# 0.003020770559838025
# 0.00010268001740423673
# 0.0001083832934882177
# 0.0007112062058214834
# 0.0007043247998865767
# 0.00537798817218258
# 6.698717455578008e-05
# 0.00028369162523956296
# 0.02208866554022163
# 0.01941904416317783
# 0.021386705608908933
# 0.01920893643615914
# 0.019093289483529893
# 0.02162408445852353
# 0.023449880988659664
# 0.019412971406106767
# 0.01882049913430128
# 0.021377377452740556
# 0.021818762069422157
# 0.023336540781330576
# 0.021416128565916247
# 0.02200130060972512
# 0.02199756344979251
# 0.08525760884112314
# 0.08567976616992486
# 0.09003213485335201
# 0.09148971187523856
# 0.08888750847011623
# 0.012396859208145844
# 0.009164478998940422
# 0.01300937613159228
# 0.006366565163566674
# 0.009865585954726398
# 0.011991048983020811
# 0.013087164527773441
# 0.00887730836777136
# 0.019699161291104036
# 0.017876816844626026
# 0.020894099139647612
# 0.020894099139647612
# 0.02088746789788191
# 0.017793466441429286
# 0.019817984058957246
# 0.017890584582263357
# 0.020898707306762902
# 0.02090041792054511
# 0.017770648299147245
# 0.028694290172366733
# 0.028266497158280154
# 0.028778316229121855
# 0.028558727510622352
# 0.028697225287078364
# 0.03437741678994639
# 0.02828096555890688
# 0.03355752861702863
# 0.03387868919306671
# 0.034643872459494664
# 0.03405134207708806
# 0.029166684877343613
# 0.028804835841826845
# 0.025880451088809583
# 0.02217342386538477
# 0.026148025799848644
# 0.025599952032903515
# 0.02239976792958504
# 0.14552051689910897
# 0.14239813526342715
# 0.14236286586974864
# 0.14587085899858102
# 0.10391131034703177
# 0.08947581096858456
# 0.10669332107868937
# 0.10926935943073225
# 0.10909497728538142
# 0.10012743726628165
# 0.10041896655290042
# 0.08969618977794776
# 0.10680978509767
# 0.10362144313211964
# 0.007941305001696276
# 0.01355407826682111
# 0.013886961361355778
# 0.010530570811847837
# 0.013177695545197592
# 0.01356977138011852
# 0.012764744977347
# 0.00298321855302449
# 0.0003189231997560448
# 0.00832090133724765
# 0.007879850775027545
# 0.005247275494504494
# 5.5806325752517924e-05
# 0.13007090059571602
# 0.13773459173646435
# 0.1337999551176809
# 0.13793091911994304
# 0.1297793430586729
# 0.1338408035104769
# 0.017818211787163578
# 0.017818211787163578
# 0.017649425302699442
# 0.017649425302699442
# 0.015258824488707806
# 0.019691268524961877
# 0.019811671301555075
# 0.019811265363252107
# 0.019700621756724174
# 0.01778126824722102
# 0.017656988332762955
# 0.020188822660029224
# 0.02147671385689863
# 0.02227845004727383
# 0.07221184921229439
# 0.07204741920347534
# 0.0721196557222555
# 0.054396045524762016
# 0.05464914365595589
# 0.05305117295886947
# 0.05024549107336077
# 0.049599632872743944
# 0.05307857752414557
# 0.26276603275411947
# 0.328444362473336
# 0.33598680370987116
# 0.33354227736516245
# 0.3021250580142913
# 0.2628286334835422
# 0.32796523315204335
# 0.263006721963755
# 0.32782919521267223
# 0.30196132432899797
# 0.05912750262460058
# 0.057826448322382235
# 0.05910367265123029
# 0.058577066757061064
# 0.05943257526024872
# 0.05973541201554492
# 0.009789296576479698
# 0.008436451322560348
# 0.013232634961156885
# 0.01261235579657616
# 0.012688100943613787
# 0.012125739423665844
# 0.009907124210656277
# 0.009558202409355492
# 0.010744835372663367
# 0.009804536382856185
# 0.009399018305745634
# 0.00828008206348771
# 0.010732968915334358
# 0.009810862947044807
# 0.004432147025728715
# 0.004236135051451396
# 0.004431267945338875
# 0.0031232619699855043
# 0.005179672959662904
# 0.04837122321288262
# 0.05095560385178972
# 0.050788661903786
# 0.24860181580189455
# 0.247411253515849
# 0.24852080235975504
# 0.24408312505949226
# 0.24479913648102022
# 0.24728629370802974
# 0.24578505937312456
# 0.24583380432313784
# 0.24487404669220736
# 0.2442415196026503
# 0.036521910520075924
# 0.03007560279894129
# 0.024482498990349
# 0.024786802185658922
# 0.03095063681315361
# 0.03294821147851291
# 0.03492011219019577
# 0.026639766829809956
# 0.027301283665578865
# 0.07529798009730321
# 0.06314190886633404
# 0.06703353739682742
# 0.07482530704220758
# 0.07991683392483846
# 0.07998649387854638
# 0.06642748039932594
# 0.0771202659470961
# 0.07453428376200322
# 0.08010788843668688
# 0.06286544069089423
# 0.01930493972279597
# 0.029783220528493123
# 0.028577516033036612
# 0.032084938123654115
# 0.03390059589390155
# 0.015541680494094295
# 0.011244763000064318
# 0.009503729416015953
# 0.007042022910873666
# 0.007119435491096558
# 0.007643328016431385
# 0.007353516810041736
# 0.007057516133698568
# 0.007509035352614255
# 0.008173844171567106
# 0.007122912257203672
# 0.007787383275238732
# 0.008493203965501694
# 0.007293004923271858
# 0.0073529351513880094
# 0.023818923674972785
# 0.02767441433828289
# 0.02767297739699976
# 0.02819564145670149
# 0.020212902305439984
# 0.020561298399181128
# 0.018367640473458433
# 0.014532043586733195
# 0.020595482614474494
# 0.020646110105687822
# 0.01733376437189447
# 0.020393974825850276
# 0.02071841274539321
# 0.04554329404268385
# 0.049454560420814496
# 0.04536126549310361
# 0.0491430483709188
# 0.04896145385238862
# 0.0002932788006520458
# 0.0003143230838895504
# 0.0013667449499733515
# 0.00331139389884803
# 6.210916853159996e-05
# 6.176618304828597e-05
# 0.0035712809093151436
# 0.0012832547357442756
# 0.03623529818346385
# 0.037786931185641685
# 0.03799083167975111
# 0.0326354993146397
# 0.041580114241193684
# 0.040996939736400055
# 0.04073884339520359
# 0.04196045886556773
# 0.03362124097959413
# 0.03447683481044102
# 0.03425821317949969
# 0.032664953854501064
# 0.03586448327317589
# 0.1485308430506002
# 0.14537240666942197
# 0.15403011387833304
# 0.1422679611674519
# 0.1451402622537427
# 0.1482652533540492
# 0.14251984323082562
# 0.15421119059407118
# 0.1679334952535175
# 0.15985980835580346
# 0.1657595403049534
# 0.1676991928957602
# 0.1661138339575348
# 0.16007322537849517
# 0.049562650402910316
# 0.0560885473259381
# 0.04920493754395155
# 0.0948212121192315
# 0.1011165327816507
# 0.09164276814428979
# 0.08554199216195801
# 0.08833101291475161
# 0.08536076660038046
# 0.09095525219087365
# 0.09457774319809882
# 0.09767854489481348
# 0.09737789349215879
# 0.08771310858112547
# 0.08958779299222115
# 0.09533146856919426
# 0.09013653677244611
# 0.09498457246395116
# 0.23866449353418712
# 0.23881022660314116
# 0.23986384615696962
# 0.2388836905065112
# 0.24142083258362224
# 0.24308639913489424
# 0.24206949901532038
# 0.2423733967532647
# 0.23983766557583028
# 0.23965423980733278
# 0.23845565922329198
# 0.23860112168634223
# 0.2418260511033852
# 0.2453698567266854
# 0.24461108227681722
# 0.24129389782479035
# 0.2411809212322231
# 0.24212675640764397
# 0.24236079333858376
# 0.24337394011896654
# 0.06942143615002158
# 0.08045266647366234
# 0.07986417472182503
# 0.07953084066413461
# 0.07793712197409768
# 0.08355336791258218
# 0.0841120813099988
# 0.0773919551626453
# 0.069151274412719
# 0.08052629822191766
# 0.07718148140109272
# 0.0858221976450933
# 0.10218275989866785
# 0.08738174920418423
# 0.08668219686641526
# 0.09122057585287849
# 0.09075284757405916
# 0.09523484985140615
# 0.1049396111687285
# 0.10358971970102107
# 0.09874042639873816
# 0.09168057133795117
# 0.08406291142515733
# 0.10439070611546293
# 0.09940051929624877
# 0.09585618689781428
# 0.0848223021615817
# 0.015277895417727163
# 0.0149000484237172
# 0.021601410252851807
# 0.0042976244232062226
# 0.004081142553875789
# 0.00010953943881378672
# 0.0003193587853102403
# 0.06531534875964427
# 0.0707848746354531
# 0.06653962481134304
# 0.07043195419956005
# 0.0608729019043293
# 0.05813861861490401
# 0.007898680367466117
# 0.007947466191374899
# 0.007904539814495253
# 0.011515893073805955
# 0.011537366470236137
# 0.009703807180226532
# 0.009981037862880964
# 0.005849540396015607
# 0.008331303222302407
# 0.00761578454467659
# 0.007966678412468606
# 0.007685424249168107
# 0.006207664881627977
# 6.416285932865135e-05
# 0.0002473052144682566
# 0.00029329798534423804
# 7.127222687655725e-05
# 4.646092273549711e-05
# 0.00028103406673001143
# 0.00028702414315499977
# 0.0012197358505898035
# 4.1093083176647686e-05
# 4.1093083176647686e-05
# 0.0003715962513539197
# 0.0028071680666503936
# 8.276538780547892e-05
# 5.9861117429447305e-05
# 0.00036696461081768317
# 0.0003644413049643497
# 0.004936233322569482
# 0.0045769304569577
# 0.0027688229793945075
# 0.08726580143637683
# 0.0869089988058971
# 0.08595064962088513
# 0.08515841465764919
# 0.023302702001014298
# 0.020128124243540456
# 0.021861257024500258
# 0.028298288555737308
# 0.022640762334393657
# 0.017465798782644044
# 0.02092679504334905
# 0.019222654251624876
# 0.0183869729813102
# 0.025399724306929626
# 0.028927381379082743
# 0.023442731557559247
# 0.0218114071085008
# 0.24830567391248895
# 0.24809991014747126
# 0.3909747283282637
# 0.3928147498945853
# 0.3907826737670462
# 0.39256900822659974
# 0.3931145614547696
# 0.3853272912837147
# 0.4160214928102029
# 0.3933293953557238
# 0.3906798022286413
# 0.39348975059274166
# 0.5367549011125331
# 0.5055655217086997
# 0.5192630327489893
# 0.5365178996956087
# 0.5053533817668697
# 9.371563349669235e-05
# 0.00010046845840866801
# 0.00010046845840866801
# 0.00010637801162936496
# 0.0003065393863718265
# 0.00028478830893003716
# 0.00028478830893003716
# 9.629858300078535e-05
# 0.00031464451320732407
# 0.00034370272194645285
# 0.030246797546371516
# 0.028626291042649517
# 0.02653188237896464
# 0.026000847559565367
# 0.025729778645723265
# 0.04241403634358059
# 0.04264549295770657
# 0.04251820027083002
# 0.04584889612549026
# 0.04285640709739576
# 0.040003663592965796
# 0.039530650004552574
# 0.04264001455807142
# 0.043819929889783095
# 0.04573912488141544
# 0.04422051919945352
# 0.23696878087424836
# 0.23700686257168063
# 0.2367785164190892
# 0.2369826507100931
# 0.2378204193916501
# 0.11751192699381
# 0.11767491916687439
# 0.11588502713940976
# 0.11390415080638197
# 0.11543265816458725
# 0.11753918835097554
# 0.11543208224721029
# 0.11766147028271191
# 0.11587161330227966
# 0.04116286211091435
# 0.26244329695556706
# 0.2625843188093885
# 0.26038829480277453
# 0.2605589796709172
# 0.25928888095268043
# 0.26078224163877284
# 0.260379609752401
# 0.26245547392453566
# 0.07021951763938898
# 0.06904569612450762
# 0.06490664466019196
# 0.07030494887973592
# 0.06556215785750563
# 0.06836175975494824
# 0.07337235006955983
# 0.06650158410702868
# 0.07031103111596869
# 0.07290666856996281
# 0.06554241628565234
# 2.456517894288579e-05
# 0.003082275422778004
# 0.002584550534474903
# 0.0006571410410265557
# 0.00028491382447050156
# 0.031192789547993375
# 0.029768811424831426
# 0.028677857381836317
# 0.028496775302508215
# 0.03142051223607495
# 0.029498808077297104
# 0.0403302984693482
# 0.03911836105324687
# 0.0329830775391218
# 0.03327089665416233
# 0.04035367298557608
# 0.03911812134136667
# 0.038741009018260594
# 0.033780935415834545
# 0.03320851887397727
# 0.03825419358744821
# 0.038542958383967985
# 0.03340026889091174
# 0.039811734917436725
# 0.015119358575229206
# 0.013441584011235205
# 0.014719069952850621
# 0.013553796406945406
# 0.01427541034394838
# 0.008568898948025821
# 0.012206226001367598
# 0.013027005501220152
# 0.012068432984192412
# 0.013565457746599669
# 0.012769244484101938
# 0.011877765596444642
# 0.015257540514450711
# 0.016338028478394072
# 0.01513179987468699
# 0.01959780352432616
# 0.01959780352432616
# 0.01959780352432616
# 0.01938663913126449
# 0.01938663913126449
# 0.01938663913126449
# 0.019587984779031304
# 0.0197876414397376
# 0.05701157551924257
# 0.054901683440672824
# 0.05683689640871937
# 0.055264840937793346
# 0.059111946904189513
# 0.0587575507543631
# 0.04623037196239175
# 0.04775489102277892
# 0.04638784347080247
# 0.04721082363307603
# 0.04940741925929516
# 0.047655567467948516
# 0.04595619990661404
# 0.04923790920633134
# 0.04742841171672391
# 0.046245802715674224
# 0.26872763320371307
# 0.2622711070663592
# 0.26884726811465476
# 0.2620458620382858
# 0.12458558524359802
# 0.12503049529229143
# 0.12785527111957587
# 0.12663969721421414
# 0.12762983227019606
# 0.12965944830616194
# 0.12997444201091765
# 0.11230517597518977
# 0.11252901148693471
# 0.1150550178884269
# 0.0015897760108515443
# 8.35625731742186e-05
# 0.0005572759648257675
# 0.00015796414007238885
# 0.0001834249166804069
# 0.0067393530808997045
# 0.00013199186368926022
# 0.006624798578612241
# 0.0052346410883403
# 0.004477012537775598
# 0.0019423887110137743
# 0.004208119938946288
# 0.004520753992321734
# 0.006285769088786522
# 0.03573412673747287
# 0.03562207705447539
# 0.033971189503259315
# 0.034121925873429056
# 0.03511729314464379
# 0.03151768593240218
# 0.027409305419276067
# 0.02989563983968861
# 0.03358697797750906
# 0.032503482242284276
# 0.031681406510581975
# 0.03207479667660604
# 0.0330650226949837
# 0.03395090317615082
# 0.026358635680594482
# 0.02271373351510626
# 0.027975440504940538
# 0.023435615673588945
# 0.02592760314799343
# 0.023160946567044927
# 0.02819726474799317
# 0.02681797400595518
# 0.027173149439322954
# 0.023463587405711132
# 0.02907275448643819
# 0.03750913701206758
# 0.028710241771486643
# 0.0619276852936172
# 0.06160442416874158
# 0.05926530521409548
# 0.060928015153377584
# 0.06174455195919478
# 0.03298477110183646
# 0.04508119085141455
# 0.04442698041952126
# 0.046358843410242614
# 0.035357177536439736
# 0.03405298841623566
# 0.0325442505654326
# 0.042815154844395575
# 0.039068343010711395
# 0.03716356495068618
# 0.05402319706349945
# 0.05282320195484474
# 0.051260863102103905
# 0.052635830949589686
# 0.051649974820754264
# 0.05422345225703664
# 0.03978878878584203
# 0.04093224879918917
# 0.03855103864801558
# 0.03883251235794284
# 0.03946143343638788
# 0.03835604188428746
# 0.04064819219563514
# 0.038097212335422286
# 0.00023888197376846184
# 0.0001824557612651096
# 0.002637775834331753
# 0.0002175644203518369
# 0.002574600760090385
# 0.0007031677709808522
# 0.021607046186576304
# 0.02178737295500255
# 0.021726574355545272
# 0.020419485115547267
# 0.018627055075693434
# 0.0160904672022043
# 0.024255261414805447
# 0.01864746667130998
# 0.022864890632136682
# 0.020353843362246455
# 0.020873387778792704
# 0.020447962315345153
# 0.021680898233502714
# 0.1573229610605029
# 0.15826952853131127
# 0.15986151672861035
# 0.15580284330350588
# 0.1579216443305598
# 0.1610933833691639
# 0.16171948460100932
# 0.1583689678288242
# 0.10616905871255404
# 0.09939683779861928
# 0.09472326144826979
# 0.09446802760614346
# 0.09935390649406915
# 0.09790769195582318
# 0.0990729874793775
# 0.09989542080523083
# 0.4265611839077321
# 0.4352749439571768
# 0.4347390016856643
# 0.42661201549354244
# 0.3133178576362896
# 0.313713074705328
# 0.3158821445506432
# 0.30769605381782716
# 0.31162943124872133
# 0.31870772757107496
# 0.3183469646372756
# 0.31157093165118027
# 0.013925046680235963
# 0.013121742997146598
# 0.01630175315163185
# 0.017223175888682985
# 0.01653790047982266
# 0.011381473835757508
# 0.016065370127988254
# 0.013317504529393207
# 0.013540869506339663
# 0.007210117238026155
# 0.012468470320863186
# 0.010393642250674882
# 0.012133956084849502
# 0.008346998528915938
# 0.007635132889942697
# 0.007635132889942697
# 0.007635132889942697
# 0.007775480073524889
# 0.007604615510823531
# 0.0840542696276724
# 0.08472862874303407
# 0.08347800608313544
# 0.08223730710458926
# 0.09153920495536258
# 0.08822173782851253
# 0.08273857720487056
# 0.08487494969707439
# 0.08421523127029014
# 0.08355890220631944
# 0.08428839143543601
# 0.08360655247529614
# 0.08494803935418127
# 0.08279702591150184
# 0.0004811858455439662
# 0.00035330833486118933
# 0.00019483186883440779
# 5.916135356700669e-05
# 0.0006057321585432656
# 0.0004913573342013185
# 0.004755159072293824
# 0.004744014056138096
# 0.0019054207446962748
# 0.0020692913563997288
# 0.0003628697633739554
# 5.435551769949549e-05
# 0.002115322465048681
# 0.1369513078893181
# 0.13707891960596807
# 0.1354882206536973
# 0.13554028864746215
# 0.1489781943070105
# 0.13545553631310897
# 0.1355601371944896
# 0.13690343350195866
# 0.13709993038908352
# 0.14383119081048334
# 0.08779105496882722
# 0.08658115074540047
# 0.0891225504498213
# 0.0902371546032089
# 0.08931383695848065
# 0.08730208416272663
# 0.087717610046813
# 0.08939309604340161
# 0.0893503980510001
# 0.09361754222334302
# 0.38848936998881545
# 0.4138266786066805
# 0.41595999014377916
# 0.4180896051661286
# 0.3952776455071347
# 0.4179786512826941
# 0.4158181838915284
# 0.4138726628949666
# 0.39538303448044354
# 0.38844038386496416
# 0.37599848674712505
# 0.3767114415516238
# 0.014187533138933402
# 0.00949817011082259
# 0.004807721880682526
# 0.005927255702714189
# 0.004355307046084661
# 0.006279561160147057
# 0.22246414398119077
# 0.23100665073960402
# 0.23207978745265362
# 0.21682983685545504
# 0.23052134705514551
# 0.23210466020422463
# 0.22854169292410387
# 0.22506081795011088
# 0.19342299885456918
# 0.20875245284005348
# 0.13024394200530742
# 0.12880755012646666
# 0.12849979224898356
# 0.23528418685985336
# 0.23539174140922606
# 0.2336825722643788
# 0.23383364526024444
# 0.243696478545772
# 0.24366008637101233
# 0.24551375236515852
# 0.2387785485884917
# 0.23370879591045593
# 0.2302161577916757
# 0.23057370222291382
# 0.24573378510491947
# 0.238988313528764
# 0.23349369321550667
# 0.00017780607180850467
# 0.003250146146550379
# 0.0003905008700452189
# 0.00022777857914172813
# 0.0038095384449780057
# 0.0006294585276995518
# 0.13108972672054128
# 0.1318458430644063
# 0.13302815494995068
# 0.13291315100334358
# 0.13184595931418014
# 0.13184595931418014
# 0.13044593518109568
# 0.13093093951458196
# 0.13028993808145733
# 0.1303654529299305
# 0.1306896643328538
# 0.13024330577888804
# 0.131547042264446
# 0.1321126194740891
# 0.0827811338320839
# 0.08283574550821499
# 0.06194947467135737
# 0.05970758435182478
# 0.05960970083893116
# 0.05524750831812522
# 0.05767152866075855
# 0.06206010777453392
# 0.06051521517836789
# 0.058351138982708314
# 0.055388913521515405
# 0.06102310986248494
# 0.14270597650492553
# 0.1445134492013349
# 0.14356778469721726
# 0.14268689519244482
# 0.14248628526230156
# 0.14090367152477895
# 0.14253485359209422
# 0.14578322750064848
# 0.1445190507318925
# 0.14287775282640663
# 0.13876600393866026
# 0.1402203778458218
# 0.118808697701745
# 0.12040081636528684
# 0.11576207114234359
# 0.11666128671400569
# 0.12001904539126027
# 0.11772844572163499
# 0.11638430434806944
# 0.11718480157347454
# 0.11901441633726724
# 0.11789728325526698
# 0.11891075869257672
# 0.12004101807492265
# 0.18166658830266674
# 0.18176783194992682
# 0.18980594521031424
# 0.1843812858643703
# 0.18184386151201234
# 0.1783120034168068
# 0.17562457027530248
# 0.18453922654576088
# 0.1816370026405074
# 0.17799952373323816
# 0.1672713389213091
# 0.17506209992398744
# 0.17176719215042693
# 0.1671164577269068
# 0.17229056254218916
# 0.1638378830802641
# 0.16768804082829372
# 0.1645522468983681
# 0.16842182927588029
# 0.17220452690700647
# 0.1842968835144681
# 0.18645296570619935
# 0.1809608384463773
# 0.17528531542904593
# 0.19229772748183507
# 0.18410061881753362
# 0.1804898308673079
# 0.17478247074836373
# 0.1866915978668625
# 0.19182607913630106
# 0.08430970153785405
# 0.08403016659937404
# 0.0807820828826319
# 0.08395479448806284
# 0.08251410383017355
# 0.0861457445910152
# 0.08453151090797598
# 0.08108344623416645
# 0.08268634551682727
# 0.08429845088539628
# 0.08619622087199362
# 0.0826665355117915
# 0.08419209473461348
# 0.08320987079782793
# 0.3222828620923755
# 0.32398543718433875
# 0.3244450329348868
# 0.3244512559479852
# 0.32243251026946074
# 0.32612344589759085
# 0.3263448071187852
# 0.32249325307138244
# 0.3216186243810206
# 0.018704144882532803
# 0.018874590696250727
# 0.018704144882532803
# 0.018704144882532803
# 0.013476489385972344
# 0.019059537649405392
# 0.019059537649405392
# 0.019059537649405392
# 0.018874590696250727
# 0.018874590696250727
# 0.01790065119909391
# 0.012719489566627834
# 0.018808600759318818
# 0.030780552228126885
# 0.032414650192849566
# 0.0329651241390027
# 0.03431602582841881
# 0.031287458310329676
# 0.025871711837797844
# 0.03195229418830005
# 0.03252021989518879
# 0.031911855932025765
# 0.0314059564902331
# 0.033908591253795854
# 0.030802215598557142
# 0.025919067057336202
# 0.026412583868848486
# 0.025273965712247812
# 0.017370455931142746
# 0.02270341312995444
# 0.023231450574332926
# 0.023292371213611555
# 0.01674863829046705
# 0.023811250142249978
# 0.017262776085641876
# 0.023738334635926877
# 0.02302362293695175
# 0.017793160981186246
# 0.07321449054932574
# 0.061628007495418566
# 0.07279425747967734
# 0.05668459927846494
# 0.06688374050184882
# 0.05461339779680408
# 0.05491812686181323
# 0.05731582179752509
# 0.06651668536786863
# 0.018736605642456466
# 0.017260124651806878
# 0.017019377249319418
# 0.01666682507779296
# 0.017237112945269768
# 0.0016707659493805796
# 0.0003818635984659541
# 0.0038633357477566017
# 0.0012259604197267437
# 6.89087446069772e-05
# 0.00400601479661912
# 0.0003864218414442095
# 0.3473122985282322
# 0.3473014382651717
# 0.09267405447417963
# 0.09672950290147285
# 0.09623433963361389
# 0.09604019426802757
# 0.09248589614157875
# 0.09681100313142392
# 0.09347152124463465
# 0.09415177852195922
# 0.09480089309785991
# 0.09114155934390612
# 0.09632315910865558
# 0.09520726292206955
# 0.0902633704886001
# 0.09337859017297817
# 0.11449300586753623
# 0.11340274307332902
# 0.11237222651759131
# 0.11286212416140429
# 0.11394036551431745
# 0.19183679132718331
# 0.18996014432413563
# 0.18894921211134255
# 0.18865947554676185
# 0.1897931157136265
# 0.1890397800725889
# 0.18896946055022132
# 0.19183630629325138
# 0.1920954659017317
# 0.19175259962973634
# 0.2902033295026989
# 0.2903234369000489
# 0.2921320033307816
# 0.2898327525346363
# 0.2877738289147071
# 0.28631016018533006
# 0.28637299200623817
# 0.29218213288577727
# 0.2898161170253887
# 0.2881638286395873
# 0.16219883774068866
# 0.16224543436871403
# 0.1623712136837532
# 0.16224207125193738
# 0.16241502685107287
# 0.16344809949932215
# 0.16073629891044805
# 0.03583352116294095
# 0.0357747237887794
# 0.039785300276259025
# 0.035138965979410026
# 0.039743816576876166
# 0.03477728795366694
# 0.04121422659782737
# 0.03851284249260171
# 0.03768096719394338
# 0.03477536658377272
# 0.039780911633030165
# 0.04047508534305771
# 0.0357692630492751
# 0.03581267728815887
# 0.0397460800283413
# 0.029989903068943963
# 0.03061035933517262
# 0.03061035933517262
# 0.029444838331012316
# 0.027413835188566934
# 0.027603742042094797
# 0.030622473445142975
# 0.03153158454071049
# 0.0715459598306805
# 0.07151557818586331
# 0.070183113279345
# 0.070183113279345
# 0.07129017439506004
# 0.07196813389864613
# 0.0717479592079132
# 0.0714349763359783
# 0.07055892625358569
# 0.04146140892424706
# 0.032527593026710655
# 0.033206170704577195
# 0.031547149712250366
# 0.036269980315601524
# 0.041430650283003335
# 0.03305783219012972
# 0.03331247469940902
# 0.03571173170938448
# 0.03237541974333135
# 0.033244864573741414
# 0.032702410188306934
# 0.03292307279811414
# 0.03318053156231652
# 0.03328503082386595
# 0.0328705447562924
# 0.03684360298533256
# 0.024938371661689402
# 0.029731286423779524
# 0.025457289600189618
# 0.03244637184977673
# 0.03538446171903301
# 0.032579727751818895
# 0.03561791606433063
# 0.037375102281253736
# 0.03011784381882172
# 0.025836446148767823
# 0.29707328710409936
# 0.29586843960737697
# 0.29357205331503156
# 0.2971893669435455
# 0.2959978386499631
# 0.110145464171658
# 0.11000730919319862
# 0.10921494431621154
# 0.1092924153478694
# 0.10563317133126827
# 0.11050067260906701
# 0.10833742430742657
# 0.10537897789472289
# 0.10692600706187626
# 0.11094949445498757
# 0.19811722476497862
# 0.19844547976933002
# 0.19602778372043791
# 0.19556190469075985
# 0.1957887402956723
# 0.1957448156368739
# 0.26351496383433787
# 0.2613071500219335
# 0.2633575327435465
# 0.2614668737561875
# 0.2663668140830498
# 0.26658733676724566
# 0.24088140653457224
# 0.2412752154898004
# 0.24094321950209557
# 0.24218508524626425
# 0.055098190827305674
# 0.05640929962307897
# 0.054998279735901
# 0.05449872023191656
# 0.0554638048247048
# 0.05465085926091204
# 0.05457392010153042
# 0.12248578304497218
# 0.12248578304497218
# 0.12248578304497218
# 0.12274646338611728
# 0.12264944159047272
# 0.12266960767253936
# 0.12257801946002563
# 0.12328012049237884
# 0.1224569991353155
# 0.12215639884531376
# 0.1512033799745822
# 0.15431328950465803
# 0.15431328950465803
# 0.15794357451629265
# 0.15794357451629265
# 0.15794357451629265
# 0.15743319218123739
# 0.15401563938201077
# 0.14932829862747307
# 0.15199873246471973
# 0.15796734142557334
# 0.15430844121263265
# 0.141084859723193
# 0.14469775538275811
# 0.14381282900187636
# 0.2484897401041798
# 0.24836608474440883
# 0.021800806149369814
# 0.024724983946189827
# 0.021743575279068176
# 0.023572758947794457
# 0.0234657185963915
# 0.02425653983474321
# 0.02192205489047525
# 0.024935982799999163
# 0.024045008777202566
# 0.18842178108567664
# 0.19248059843766332
# 0.19105971393373228
# 0.1945004107547506
# 0.1796617469895063
# 0.18163724290598857
# 0.1944060850864086
# 0.16090206029772142
# 0.1601726168181892
# 0.13102430800766793
# 0.13134297571624812
# 0.12514060429822227
# 0.12534068064825707
# 0.12208492283154371
# 0.1226090661810517
# 0.1370957630617083
# 0.13927078811771942
# 0.13622686406989415
# 0.13460854952439338
# 0.13531525289214197
# 0.13531395816499134
# 0.1332406010065014
# 0.13346536299454761
# 0.13508331055508557
# 0.12754195366973123
# 0.1265138463703722
# 0.12561897199530445
# 0.1296755433297476
# 0.1267639834350167
# 0.12770040609124347
# 0.12757172389625757
# 0.12926100336329074
# 0.12747630327465234
# 0.12589430220117281
# 0.12677297868147763
# 0.12776617761189873
# 0.12748893174693304
# 0.12524405420789356
# 0.12322562860263879
# 0.12383768911553834
# 0.11888265856554417
# 0.12108915084506153
# 0.12308576621644526
# 0.12025658139592171
# 0.11905081205505735
# 0.12347245135421266
# 0.12285139927992123
# 0.03306891332564183
# 0.03306891332564183
# 0.03574360697652087
# 0.03668158927894465
# 0.0331622359918743
# 0.037465923613292845
# 0.03934663177920746
# 0.04086358936728799
# 0.034090411560485374
# 0.03926420939441616
# 0.04043719491653256
# 0.008697443128925725
# 0.008855624713909743
# 0.008696464797929798
# 0.010107613102584729
# 0.010254854699950126
# 0.008861394543449442
# 0.03225373689728199
# 0.03320464315344488
# 0.0362107637924482
# 0.03841915439905648
# 0.03594629691862169
# 0.03208330570043361
# 0.03287281410090554
# 0.03803364777936019
# 0.11451072057358312
# 0.1180327383404043
# 0.11658367809568063
# 0.11892561066068173
# 0.11805788789350584
# 0.11493826122825475
# 0.118683118235479
# 0.11586420286796446
# 0.6068909145126584
# 0.606942976774351
# 0.1263701033433678
# 0.1301400154686967
# 0.1318589993717266
# 0.12620096756002164
# 0.13176000238245875
# 0.12946736133074593
# 0.12747298625639805
# 0.1239001500444037
# 0.1254560214120395
# 0.12588123437156673
# 0.12442477143893922
# 0.12738927449006238
# 0.1322098142151774
# 0.13531042447179806
# 0.13415186605135704
# 0.13244070876824712
# 0.13242767556271176
# 0.11616207444790957
# 0.11675696205606256
# 0.11745622212329489
# 0.11613947878713278
# 0.13507264517046386
# 0.1366429037277513
# 0.13491623610940517
# 0.1365132825598664
# 0.2770536012571363
# 0.2751485632959473
# 0.27704610251778794
# 0.27514196874539637
# 0.2168850720787043
# 0.22859126185638726
# 0.21672415356997507
# 0.22989654172950236
# 0.07794236499759466
# 0.077449594269102
# 0.05656530400984117
# 0.07681147395809808
# 0.06226935266706089
# 0.058155024118294166
# 0.062437341904584984
# 0.056765891019680964
# 0.059430563767115654
# 0.05627541039394078
# 0.05333046816683853
# 0.05803713827371886
# 0.07779043739660402
# 0.049605123096220664
# 0.053445006833199096
# 0.010575655378200039
# 0.010616281382278091
# 0.013591014787767336
# 0.01360099841802902
# 0.01395373042815704
# 0.03388357457908816
# 0.03943658793044729
# 0.04424680377175923
# 0.032556254950661
# 0.03274116635138762
# 0.0343254315508616
# 0.03289624914549097
# 0.03268925046311373
# 0.04189566072475351
# 0.03646108256399266
# 0.03404551522089074
# 0.03634961571278515
# 0.21872485578847362
# 0.21153965153503354
# 0.21208682180923155
# 0.2117580410950271
# 0.2186709694930353
# 0.23654551855867842
# 0.23647363408046135
# 0.2571772924855781
# 0.2573804242204105
# 0.2703866424453653
# 0.2713948279890756
# 0.27156159879910213
# 0.2733924806527361
# 0.26972710605333694
# 0.27102888339685477
# 0.2710677246867229
# 0.27150634469410345
# 0.27117513007410277
# 0.2694931202802786
# 0.27282184017693656
# 0.12843938645622438
# 0.13174611976881806
# 0.128493778134181
# 0.13176196177589017
# 0.12836496133442757
# 0.1311403789958702
# 0.13265997927727297
# 0.1306407766683521
# 0.13095078989416317
# 0.12741563140853168
# 0.13022292135643904
# 0.09906104216627369
# 0.0993509012756864
# 0.26526285767069147
# 0.2655346679064042
# 0.08468795722955724
# 0.08910420098223534
# 0.08447773628850186
# 0.08415769396558218
# 0.08607675270884879
# 0.08943562156704067
# 0.0853706406506142
# 0.08428523512632968
# 0.08489468954186921
# 0.1991852241209704
# 0.20025682182331395
# 0.2031261718065534
# 0.21258981173881844
# 0.20726451968376275
# 0.19003234422536425
# 0.1994074084558883
# 0.2128414946507176
# 0.20477141299118878
# 0.20624453036448406
# 0.20674722794836856
# 0.20312677113364358
# 0.1810176497982515
# 0.17945616827268732
# 0.18109041142396806
# 0.06548775636726538
# 0.06402754992918078
# 0.06080004679183256
# 0.05812914171655723
# 0.057166162729411794
# 0.060768183540906254
# 0.06347766166006659
# 0.1352122545747557
# 0.13126858519870024
# 0.13111696606142037
# 0.13572838722342018
# 0.13611957302036118
# 0.1338305786899729
# 0.1334566848045658
# 0.13561980244203653
# 0.12087966804453823
# 0.12155757137635796
# 0.1334557634294876
# 0.06788109093171325
# 0.06590541343028455
# 0.0686850973735832
# 0.06889591476556697
# 0.06564334845429601
# 0.06828747996623621
# ...
# 0.0094732177159645
# 0.009868046716940653
# 0.00424399600304938
# 0.013762654528020238
# 0.010239973876062843
# 0.013797600559856389
# 0.0907507931504544
# 0.09257701516070495
# 0.09066356305118249
# 0.09032421987616412
# 0.09272046171012946
# 0.09156111968912585
# 0.08955748716943314
# 0.1185308768327495
# 0.10983799782451197
# 0.11857300250771169
# 0.11890862631148172
# 0.11896689321085192
# 0.11863753533771833
# 0.11007747713756336
# 0.09729281274199642
# 0.09063102518647169
# 0.09192004195818962
# 0.09400262840731677
# 0.09646951004219669
# 0.09461672338736246
# 0.0944520136436251
# 0.0942828876485116
# 0.09286284745471872
# 0.09298772373307529
# 0.09416188508415485
# 0.09065851747511862
# 0.1441476500017022
# 0.14631671513024666
# 0.14503190527897294
# 0.144090210691523
# 0.14452604217288906
# 0.1638103023468897
# 0.16298484779418207
# 0.1594113233486679
# 0.1630392493385066
# 0.16436357034827118
# 0.1450910680257488
# 0.16149435006545482
# 0.1446895964400025
# 0.14700258373579791
# 0.14787396040038328
# 0.15075186291464596
# 0.14472336036053773
# 0.1462288669810369
# 0.15078923091043053
# 0.08864912716575463
# 0.08803615768394556
# 0.10056832879239477
# 0.09538793029888479
# 0.09268838238292952
# 0.09362446150859524
# 0.09396143659362803
# 0.09883782023733968
# 0.0964208764025174
# 0.09802709304663863
# 0.09371515428966144
# 0.09758281787100821
# 0.10275891487017715
# 0.028568310673263587
# 0.03645717772097037
# 0.03642382188851177
# 0.03335131098191124
# 0.03179469859486056
# 0.032901611219813914
# 0.034394158933623555
# 0.02764541460529987
# 0.03216602344661515
# 0.028097468564457547
# 0.0347426069679467
# 0.058029522379806235
# 0.058415364385967214
# 0.05794548270544469
# 0.06542488042625028
# 0.07668228652774577
# 0.07664064888843242
# 0.07438443371969722
# 0.06508945111945301
# 0.11942351078286485
# 0.11957401962640789
# 0.12108006595134825
# 0.12362606854992922
# 0.12024455278028752
# 0.120966247947259
# 0.12214672438551157
# 0.12278518953144625
# 0.12226052218297677
# 0.12160569951383364
# 0.11973872845030023
# 0.12392862423878534
# 0.1230868971093212
# 0.08962403492147036
# 0.08983950936757804
# 0.08856853351919036
# 0.08675840043080159
# 0.0898027702479747
# 0.08963941492287739
# 0.08918891665162526
# 0.08681236397392857
# 0.08486302347885494
# 0.08476067152148357
# 0.08727708389912418
# 0.13347514576331573
# 0.1343980992359948
# 0.13343509366865977
# 0.13337357272607414
# 0.13311427283049165
# 0.13446041761400065
# 0.010401227341880898
# 0.009404041470032135
# 0.016603962271593345
# 0.010144518827809491
# 0.00029872563244610564
# 0.0036973130737394558
# 6.642670381957348e-05
# 6.922838981271886e-05
# 0.003694705396571551
# 0.00029593867246154325
# 0.030164417029868065
# 0.030312301695087713
# 0.030401435919096022
# 0.03143114042036357
# 0.02965034764123424
# 0.1184161692834994
# 0.11229743544905808
# 0.11230607490652042
# 0.06163901899454211
# 0.06181338124870163
# 0.2011198989766258
# 0.19920193690354213
# 0.19934051418022067
# 0.06827537061697757
# 0.06824916799086318
# 0.06813274321634206
# 0.08337059533279507
# 0.08729178058163731
# 0.08599552512882341
# 0.0855707328688134
# 0.08604720006031417
# 0.08724557304152886
# 0.08593625588984041
# 0.08877099761810592
# 0.08352696931560899
# 0.08848549761733288
# 0.0903405530498521
# 0.09039358975095574
# 0.08993557650677131
# 0.08371471646104678
# 0.08352577552658207
# 0.09062334735214228
# 0.09024284425880484
# 0.08865829767606215
# 0.08854641058025567
# 0.06956938175103623
# 0.06740596218103947
# 0.07092787622585926
# 0.07116214959837042
# 0.06573463299885739
# 0.06719557316244111
# 0.06601467307757788
# 0.06932752567767103
# 0.06605028212197236
# 0.06980665943303496
# 0.06622806795287675
# 0.06966231734867188
# 0.11447232769038047
# 0.1145604156732771
# 0.11495422346236962
# 0.1149621855162774
# 0.11485358626047108
# 0.11448724224135655
# 0.11343831127244207
# 0.11491933307150938
# 0.11445107916309574
# 0.11653369328714495
# 0.1164181787726708
# 0.11295210827350337
# 0.11033467695022715
# 0.07473403644970963
# 0.07558008005119764
# 0.07496435991138707
# 0.07320345232029227
# 0.0734192336015777
# 0.01199776579364304
# 0.010455415784824347
# 0.007819295036370046
# 0.0784788758658584
# 0.07947632664420216
# 0.08477520235903814
# 0.08414087938545467
# 0.081607232419862
# 0.07899934760806525
# 0.08157315942759376
# 0.08367836486664827
# 0.08418807617330229
# 6.418062488859608e-05
# 6.598761353144577e-05
# 7.681704222177112e-05
# 0.00040623325608110303
# 9.55398155785805e-05
# 6.56834034902669e-05
# 0.0002990255384268597
# 0.00034975527923977934
# 0.0003012817875752235
# 0.056000987654414205
# 0.052215510742380615
# 0.05328133364369785
# 0.02490307999298673
# 0.02766415008159505
# 0.031520930360386584
# 0.034739453850882646
# 0.03723260251327265
# 0.026938256856834424
# 0.03840007839940824
# 0.02688816892702049
# 0.06397574320967409
# 0.06271652266962287
# 0.05529193163814143
# 0.058513812518161186
# 0.05544884643692574
# 0.058412538099304724
# 0.13718419661607245
# 0.13694555820514195
# 0.07781282133104264
# 0.0892286708011955
# 0.09133027565381344
# 0.07736801068262708
# 0.09136538516114656
# 0.09409827510719855
# 0.08934853708833125
# 0.19515864608679515
# 0.19504361551310803
# 0.19342015126483844
# 0.19361369216033802
# 0.05300647107229813
# 0.0502997624488337
# 0.05082531395366443
# 0.05266559637943443
# 0.0823299876537056
# 0.08507800277744763
# 0.08491665549579096
# 0.08276308849082348
# 0.08046056480846323
# 0.07870321233201992
# 0.08001932812497103
# 0.07833467629061458
# 0.0777452309713173
# 0.07046002587344342
# 0.07684222869562067
# 0.07697474270335271
# 0.07171821901466965
# 0.13936317401217121
# 0.13900808130943848
# 0.2265917962206053
# 0.22499525517522742
# 0.22678349101750692
# 0.2036127077569912
# 0.2075321880290193
# 0.2139966405223323
# 0.22466645458079543
# 0.20766129881643605
# 0.20368510504608514
# 0.2214779285493054
# 0.2212150487588921
# 0.21379117446064813
# 0.14620853645809842
# 0.14590381072465516
# 0.14822523343346705
# 0.14816718927958367
# 0.14310182299196703
# 0.15031184532869063
# 0.14805221915158953
# 0.14698285409101422
# 0.14588731413158781
# 0.1428709270134916
# 0.1483143097262787
# 0.15078668634310013
# 0.14724808108922324
# 0.146149861622399
# 0.16788911235534218
# 0.16527508534884078
# 0.1656718429787645
# 0.16580993335082578
# 0.17741523251134494
# 0.016490886591033337
# 0.010693823015456518
# 0.016112945482146257
# 0.013231423472901058
# 0.01331648132957718
# 0.01644308002126566
# 0.01651268733228041
# 0.011108268879607152
# 0.012771423496287211
# 0.03581878892148698
# 0.035118655973740684
# 0.036101525604545846
# 0.03485241900434497
# 0.035457356219848093
# 0.03511705583464151
# 0.03583285358553954
# 0.03950995028738966
# 0.03986469271941494
# 0.01332877954359821
# 0.00624522972713042
# 0.006245853902348863
# 0.007814700131322702
# 0.007815746766251554
# 0.00781475639436064
# 0.007535648264433675
# 0.0078098305843294635
# 0.013337514897799498
# 0.006241966447079786
# 0.006255948186759592
# 0.01372744402651507
# 0.006536072749813655
# 0.24165765211393583
# 0.2403361470124687
# 0.23232694471502693
# 0.2427360589299023
# 0.23847472227975366
# 0.23536871651526883
# 0.2322965960769909
# 0.2404688079650219
# 0.23888023943210718
# 0.22103982799444188
# 0.21921239019264074
# 0.21930092949834454
# 0.22046108892609545
# 0.2234899768377198
# 0.22318678834617645
# 0.2210432114910324
# 0.22540083114441137
# 0.22412319793408944
# 0.22490175754990627
# 0.22213354024282625
# 0.22457592496621967
# 0.22200605773619425
# 0.025458895717955305
# 0.030181434414861118
# 0.02941428823870929
# 0.029072185542616466
# 0.025095124307794446
# 0.020787268773480746
# 0.020070199646018937
# 0.029702388367964624
# 0.027639953597516337
# 0.031587892361685514
# 0.03017287491913995
# 0.03954311565004043
# 0.03584021413974817
# 0.03628985226354894
# 0.03553829678190579
# 0.03462621389716341
# 0.03439056130904605
# 0.034660148741439877
# 0.037055913550972944
# 0.034151307732320654
# 0.03724141471345716
# 0.039415054309553735
# 0.036303489561146936
# 0.036717616583462905
# 0.03575426982739592
# 0.03659022790393916
# 0.00993343769404415
# 0.010869361091007924
# 0.007425805775544312
# 0.005021429484783293
# 0.004759609227241287
# 0.007752428494417921
# 0.006834743956159464
# 0.008089972574586435
# 0.011571465448402846
# 0.006547153386942657
# 0.10419187658604459
# 0.10431015748784693
# 0.0003274339579185858
# 0.0002282377895203013
# 0.00017762519851039873
# 0.00023383812853197211
# 0.00017815011558751302
# 0.000271666857829465
# 0.0003599573431969796
# 0.0006782411767456347
# 0.0006346042291072713
# 0.0016354657584335183
# 0.0007063832916791851
# 0.0008897800814733765
# 0.0007434566724701081
# 0.01360102056807322
# 0.015529288202293377
# 0.01919392647783122
# 0.019245687450018326
# 0.015600029891715522
# 0.020281139052773685
# 0.023505037597307835
# 0.021593430591951297
# 0.01781562741537439
# 0.023827918528861736
# 0.027348300849946588
# 0.1703370779280447
# 0.17139479985905318
# 0.16167571955890483
# 0.16141194353797003
# 0.16940108812989155
# 0.06613263125727924
# 0.06259946378668743
# 0.06053402893887608
# 0.06007821791162437
# 0.06159840223821487
# 0.06143619459180936
# 0.06459100716202212
# 0.0659933952211437
# 0.06409844383987678
# 0.018286198789917715
# 0.012425052434773515
# 0.012528001390664602
# 0.017756282669728295
# 0.014570453721495893
# 0.015929175495961425
# 0.01150107455762707
# 0.008748100340325032
# 0.008669497747632348
# 0.05284360069487841
# 0.05549888228633858
# 0.05332500188775317
# 0.05243533377402763
# 0.05278885082685311
# 0.045614022794540944
# 0.04756147644834248
# 0.05190359769791126
# 0.14365201365555388
# 0.14367244027148568
# 0.14540990742156532
# 0.14552787652474003
# 0.14376963778006888
# 0.19248503951868537
# 0.1566807421167741
# 0.1788276475021276
# 0.19249204623078642
# 0.18457321680293823
# 0.16982191372829383
# 0.1859972600248457
# 0.1858891425810465
# 0.18435104074764466
# 0.17878737905469938
# 0.1758497423651953
# 0.175701361798916
# 0.1701017322842352
# 0.11381686981138668
# 0.11384829269226905
# 0.11028025079214886
# 0.11207291858589458
# 0.11347040143417068
# 0.10820240229766942
# 0.11192041375924693
# 0.1084193389990693
# 0.11364135256198536
# 0.1099222321800296
# 0.005766029711268503
# 0.00027928051499998317
# 0.0002376906156388153
# 0.00017738599963313938
# 0.007888767537061876
# 0.006001161433631386
# 0.007586959396886938
# 0.0006484061681482664
# 0.004172835082235702
# 0.004407511456750118
# 0.1458968314037163
# 0.14579810114454533
# 0.14615100297222874
# 0.08883956404830126
# 0.08685108426046341
# 0.08864651495733258
# 0.08854168383212915
# 0.08857752410269856
# 0.08838650658276609
# 0.12422626221417275
# 0.12390211466185386
# 0.11784929415426612
# 0.11781052055586023
# 0.12355567398594505
# 0.12111479915412028
# 0.12094828479692071
# 0.08896289481190206
# 0.0874509254096212
# 0.08880948899905447
# 0.08748270647262318
# 0.09410197697651668
# 0.09230007875367592
# 0.09352490736618642
# 0.09430154085561769
# 0.09240526957984015
# 0.08656564445549243
# 0.09798122096216487
# 0.08555206279834078
# 0.08899376857554753
# 0.0891856123903485
# 0.09750042201866345
# 0.07951980532027335
# 0.08379820383009501
# 0.08131599454430602
# 0.07836034200555775
# 0.07950779883880502
# 0.07807035841860929
# 0.07974135494356668
# 0.08106801549957951
# 0.08224012269883224
# 0.01711948189740753
# 0.01723293873488157
# 0.01834786331718057
# 0.024156041502602237
# 0.02483146445383961
# 0.0225304292162768
# 0.01620601701122979
# 0.020300057109797633
# 0.02332626243573732
# 0.02005803684729879
# 0.03067907864403746
# 0.022970881062841148
# 0.01619391095256101
# 0.016834615518607484
# 0.018334337114489622
# 0.020023621746337924
# 0.018396173986578987
# 0.015946650458398277
# 0.0003201280594606987
# 0.015622566426464465
# 0.01621165457365982
# 0.015770000419558748
# 5.9952398550598534e-05
# 0.00029578430664039027
# 0.016017386421708156
# 0.019682493214776487
# 0.11324309458974749
# 0.11304407927501277
# 6.298612593636275e-05
# 0.00029568538464415573
# 6.439320796871764e-05
# 6.22240199285917e-05
# 0.0003065343755666782
# 0.0002997327816273803
# 0.008767007560425526
# 0.011853114144368949
# 0.005170896378683724
# 0.005123524325296669
# 0.10105057070669365
# 0.09524428191706456
# 0.10186782798655074
# 0.094804310547241
# 0.09859563124489851
# 0.09940848874578277
# 0.09950936222980453
# 0.10338564926767667
# 0.10422186616718887
# 0.10043430096303567
# 0.10228144104998944
# 0.10218659230863965
# 0.09739057577075377
# 0.06756839962408702
# 0.07404865058017507
# 0.07383483673245786
# 0.0672814174524749
# 0.06718939920118033
# 0.07465011010055864
# 0.07589353079473977
# 0.07452370943489309
# 0.0761739496892253
# 0.07236233301867243
# 0.07263803925661325
# 0.06871122812120838
# 0.06895086136554296
# 0.0018978421936117458
# 0.0013090055778409073
# 0.00635663973295748
# 0.00716505014043261
# 0.0011711859965844885
# 7.306614703897358e-05
# 0.007719504458675058
# 0.000869408045122586
# 0.0063524491512937
# 0.003589702784488145
# 0.007945555516527028
# 0.0034730362095229572
# 0.007941448564858063
# 0.00031485426033940736
# 7.29767396179963e-05
# 0.2106034355929761
# 0.21346229023992466
# 0.21348120413400112
# 0.21375186855623632
# 0.21252378401964808
# 0.21249826229515364
# 0.21329531435079438
# 0.21170339240205063
# 0.08342639970724632
# 0.0968633120346677
# 0.08338377308055799
# 0.09659947798294785
# 7.693710729355868e-05
# 0.0035422219845262317
# 0.00029983184126239603
# 0.03549563395380761
# 0.03255197824342332
# 0.032766414815870365
# 0.035436990081371314
# 0.03313138081166473
# 0.0298888935469247
# 0.026912446959288516
# 0.03379437152450589
# 0.03264948303014938
# 0.031599618901094674
# 0.035955004082947044
# 0.03672898875832663
# 0.0325177598044361
# 0.03269949622832674
# 0.02737961973723417
# 0.03574400187339615
# 0.03578259732518197
# 0.03363403939894541
# 0.03514729525239371
# 0.00785806753186409
# 0.006247639119840886
# 0.006250839718775071
# 0.007850153818608787
# 0.013330900611852848
# 0.007834467172183397
# 0.007553803527483209
# 0.0078366542564725
# 0.013327698563922085
# 0.006257000687185654
# 0.006274285792026768
# 0.013717348042694767
# 0.013720906789645677
# 0.006545002259027412
# 0.21772384353447505
# 0.21798157440940713
# 0.22202751932784165
# 0.2186325472137732
# 0.21985397251102012
# 0.2177973104117569
# 0.2172902487836787
# 0.21888025998361635
# 0.21858560992268908
# 0.2220206535967055
# 0.21845304640095045
# 0.22036678934243661
# 0.03271089923294364
# 0.022219026593100637
# 0.025342204193078453
# 0.035027103622749224
# 0.025924254066446974
# 0.022440827980556598
# 0.03280285368850715
# 0.21960786506865382
# 0.2193529662181177
# 0.21565180600821016
# 0.2168733110283671
# 0.2157344448640231
# 0.21153288822791114
# 0.21290911303182236
# 0.2109152857741043
# 0.21521452084563786
# 0.21354705179238193
# 0.21265293479538677
# 0.21135039915158596
# 0.2158170238064576
# 0.20563021725769962
# 0.20416636277370528
# 0.20260815040035113
# 0.20285324729532944
# 0.20432107401882485
# 0.20807694197549945
# 0.20819491425944858
# 0.20510877829996454
# 0.20550835016118316
# 0.20406806016365472
# 0.2053560109095016
# 0.2088819613167924
# 0.20824405793070955
# 0.016488556996214345
# 0.023220046765705535
# 0.011732950553490848
# 0.010174396347287614
# 0.010441980733259961
# 0.016230364052936787
# 0.020867728576133494
# 0.023331853202083853
# 0.013480042614473787
# 0.01654003645665021
# 0.016621731531999178
# 0.020514437758811083
# 0.013262441813811286
# 0.013357393048366927
# 0.014007529231730076
# 0.01579830437131904
# 0.020512254302856914
# 0.020286262184489954
# 0.01602784230806021
# 0.012604510934120579
# 0.018581817070850524
# 0.15233591068530258
# 0.14956823485875387
# 0.1491056080813939
# 0.15256842211070717
# 0.14961935507620613
# 0.15913910789139302
# 0.15182102441921053
# 0.1589629549608413
# 0.15179836443755781
# 0.09416081201460154
# 0.09134007987661856
# 0.09507883490470911
# 0.09140374503622667
# 0.09127337350878002
# 0.09268197756524457
# 0.09163902930681249
# 0.09164756638024513
# 0.09390882826124793
# 0.09498321965842767
# 0.09278252248030357
# 0.09314143082734494
# 0.09519135538142723
# 0.09525984715518082
# 0.09446640608808088
# 0.00863153112395169
# 0.00925772503415668
# 0.25620561687878596
# 0.25620465014714006
# 0.25205535395174855
# 0.2522734855512177
# 0.23208380870224668
# 0.25637782473062476
# 0.23213964319258237
# 0.23194711001604415
# 0.25626024352701127
# 0.23202906724830455
# 0.1868241756148116
# 0.1882149066526672
# 0.18649265164824064
# 0.18784923515458926
# 0.18100996544868705
# 0.17736920003445306
# 0.17747917961316206
# 0.18110806646051672
# 0.18772308083539774
# 0.18804208750288187
# 0.14861382815533286
# 0.14419278017039916
# 0.1508995810701829
# 0.14924566818079676
# 0.15042841886222633
# 0.14864446346947957
# 0.14677567799019828
# 0.14516668135549116
# 0.1468142487414228
# 0.14529876167139624
# 0.1716492423539708
# 0.13702421696368894
# 0.1304270893846152
# 0.11695399598800972
# 0.1236717539168848
# 0.12015744042322482
# 0.11678564986037285
# 0.12577718365312848
# 0.13342119315436346
# 0.12039812102630149
# 0.12681871693595664
# 0.1301372425229607
# 0.12707326236471567
# 0.123744502425084
# 0.13341016603831385
# 0.17915525194480028
# 0.18241158016147144
# 0.18332623862477876
# 0.18593357131225963
# 0.19094993884263936
# 0.18911527743768444
# 0.21743407373667756
# 0.173665467470963
# 0.17384651085076294
# 0.16487295435565655
# 0.16345718558165537
# 0.16362941724470537
# 0.1861476102636039
# 0.2174732200795831
# 0.17724866958922536

# %%
linestringLinhas = linhas[linhas['sentido']=='IDA']
for i in range(linestringLinhas.shape[0]):
     line = linestringLinhas.iloc[i]
     display(line.linha)
# Out:
# '0.018'
# '0.946'
# '0.373'
# '503.3'
# '531.1'
# '0.851'
# '330.1'
# '0.522'
# '519.3'
# '0.520'
# '932.4'
# '0.550'
# '0.853'
# '0.882'
# '807.4'
# '617.2'
# '920.4'
# '0.883'
# '156.7'
# '1001'
# '515.6'
# '506.4'
# '2205'
# '0.958'
# '0.555'
# '376.2'
# '759.1'
# '206.9'
# '504.5'
# '305.4'
# '0.305'
# '136.9'
# '300.1'
# '823.2'
# '0.181'
# '156.9'
# '0.101'
# '0.322'
# '0.175'
# '167.1'
# '0.370'
# '158.3'
# '348.1'
# '147.2'
# '807.8'
# '0.624'
# '0.382'
# '0.394'
# '557.1'
# '373.2'
# '761.1'
# '194.1'
# '501.2'
# '136.6'
# '0.871'
# '600.2'
# '519.1'
# '501.3'
# '322.1'
# '190.2'
# '844.2'
# '180.2'
# '396.3'
# '100.8'
# '413.2'
# '0.420'
# '0.421'
# '413.4'
# '136.7'
# '2306'
# '199.1'
# '340.1'
# '197.3'
# '611.1'
# '0.412'
# '0.403'
# '0.404'
# '0.930'
# '413.1'
# '0.503'
# '0.611'
# '3317'
# '100.9'
# '0.773'
# '0.884'
# '638.1'
# '0.819'
# '0.511'
# '616.3'
# '392.2'
# '813.2'
# '630.2'
# '501.7'
# '3311'
# '423.1'
# '0.527'
# '136.3'
# '181.4'
# '411.1'
# '0.913'
# '100.2'
# '808.1'
# '196.2'
# '170.1'
# '807.9'
# '0.911'
# '0.622'
# '0.346'
# '0.374'
# '374.2'
# '0.756'
# '0.526'
# '0.771'
# '0.878'
# '963.1'
# '0.850'
# '172.7'
# '0.640'
# '0.903'
# '0.513'
# '871.3'
# '206.3'
# '0.377'
# '0.617'
# '0.182'
# '643.1'
# '323.2'
# '154.3'
# '147.7'
# '382.1'
# '806.1'
# '616.4'
# '181.1'
# '400.2'
# '0.376'
# '376.3'
# '305.6'
# '910.1'
# '411.2'
# '0.764'
# '0.942'
# '376.1'
# '0.378'
# '0.808'
# '180.0'
# '160.1'
# '0.198'
# '0.314'
# '0.818'
# '0.806'
# '624.1'
# '0.317'
# '0.762'
# '0.375'
# '372.9'
# '0.918'
# '515.3'
# '0.834'
# '373.3'
# '0.199'
# '808.5'
# '540.1'
# '335.1'
# '0.258'
# '147.9'
# '0.215'
# '336.1'
# '147.4'
# '160.2'
# '533.1'
# '398.1'
# '0.821'
# '0.424'
# '600.3'
# '850.1'
# '182.2'
# '2303'
# '0.153'
# '336.2'
# '0.380'
# '386.1'
# '343.2'
# '504.4'
# '760.1'
# '825.1'
# '0.768'
# '0.205'
# '0.234'
# '0.841'
# '0.331'
# '0.162'
# '3312'
# '942.2'
# '604.3'
# '0.525'
# '0.330'
# '0.631'
# '0.962'
# '147.3'
# '616.6'
# '0.185'
# '100.4'
# '0.953'
# '367.8'
# '374.1'
# '640.1'
# '197.1'
# '0.147'
# '519.2'
# '0.554'
# '147.5'
# '0.910'
# '0.519'
# '0.194'
# '379.1'
# '2202'
# '630.1'
# '0.781'
# '0.255'
# '780.1'
# '0.881'
# '158.4'
# '389.1'
# '0.310'
# '640.2'
# '152.3'
# '188.1'
# '620.1'
# '132.3'
# '0.400'
# '0.906'
# '0.638'
# '805.7'
# '512.1'
# '0.300'
# '0.516'
# '3310'
# '0.340'
# '0.769'
# '2203'
# '306.5'
# '0.338'
# '0.216'
# '0.954'
# '0.405'
# '0.160'
# '334.4'
# '0.552'
# '0.324'
# '0.385'
# '600.8'
# '206.8'
# '0.763'
# '0.180'
# '602.1'
# '932.1'
# '616.5'
# '0.604'
# '0.605'
# '0.835'
# '384.1'
# '0.391'
# '0.616'
# '616.2'
# '306.2'
# '844.1'
# '604.1'
# '604.2'
# '764.2'
# '932.3'
# '0.517'
# '0.760'
# '605.1'
# '515.4'
# '346.1'
# '550.1'
# '0.907'
# '380.4'
# '615.1'
# '0.558'
# '811.1'
# '902.2'
# '932.2'
# '0.392'
# '173.1'
# '0.366'
# '0.334'
# '0.170'
# '506.0'
# '0.627'
# '2206'
# '0.186'
# '180.1'
# '0.167'
# '0.301'
# '600.7'
# '255.2'
# '170.6'
# '100.6'
# '517.2'
# '396.2'
# '158.6'
# '0.224'
# '0.518'
# '648.1'
# '087.5'
# '0.275'
# '207.2'
# '874.4'
# '0.349'
# '180.3'
# '504.1'
# '2309'
# '0.531'
# '0.556'
# '366.5'
# '0.641'
# '383.3'
# '616.7'
# '340.3'
# '380.2'
# '0.312'
# '0.602'
# '343.6'
# '865.1'
# '509.1'
# '2208'
# '0.960'
# '0.092'
# '0.601'
# '942.1'
# '625.1'
# '379.2'
# '190.4'
# '394.1'
# '0.197'
# '0.816'
# '066.1'
# '163.1'
# '206.2'
# '194.2'
# '2212'
# '0.195'
# '2310'
# '206.5'
# '0.348'
# '0.811'
# '338.1'
# '0.411'
# '0.339'
# '870.1'
# '197.6'
# '158.7'
# '260.3'
# '616.1'
# '0.345'
# '322.2'
# '0.273'
# '0.643'
# '0.379'
# '806.8'
# '642.1'
# '397.2'
# '0.914'
# '3211'
# '0.196'
# '0.920'
# '0.176'
# '313.2'
# '0.761'
# '0.813'
# '391.3'
# '0.600'
# '0.620'
# '603.1'
# '147.6'
# '2307'
# '845.2'
# '101.8'
# '0.603'
# '805.3'
# '160.3'
# '0.780'
# '2301'
# '2201'
# '156.8'
# '823.1'
# '383.1'
# '0.504'
# '870.7'
# '511.4'
# '158.2'
# '3313'
# '0.648'
# '0.129'
# '324.1'
# '0.825'
# '0.902'
# '600.4'
# '760.2'
# '366.7'
# '197.5'
# '531.3'
# '156.1'
# '306.1'
# '154.2'
# '205.1'
# '0.372'
# '0.515'
# '0.810'
# '0.822'
# '398.3'
# '2302'
# '0.253'
# '642.2'
# '0.383'
# '505.4'
# '0.765'
# '0.642'
# '0.886'
# '818.1'
# '0.759'
# '813.1'
# '761.2'
# '067.1'
# '197.7'
# '0.965'
# '101.1'
# '2308'
# '872.3'
# '0.158'
# '0.171'
# '0.397'
# '0.343'
# '642.3'
# '0.371'
# '380.3'
# '366.1'
# '207.3'
# '0.132'
# '157.9'
# '600.5'
# '394.4'
# '0.509'
# '670.3'
# '158.5'
# '372.2'
# '0.966'
# '870.9'
# '0.932'
# '0.306'
# '0.225'
# '807.1'
# '501.1'
# '0.845'
# '2210'
# '0.159'
# '0.670'
# '0.809'
# '157.5'
# '0.521'
# '0.876'
# '844.3'
# '0.900'
# '310.1'
# '180.6'
# '180.5'
# '501.5'
# '0.512'
# '337.1'
# '600.6'
# '0.399'
# '0.501'
# '0.336'
# '206.1'
# '385.1'
# '0.823'
# '401.1'
# '637.2'
# '0.347'
# '100.3'
# '0.873'
# '0.844'
# '0.172'
# '805.6'
# '506.2'
# '813.3'

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium
import pandas as pd

# Filtrando a linestring apenas pelas linhas de onibus de ida
linestringLinhas = linhas[linhas['sentido']=='IDA']
linestringLinhas = linestringLinhas.to_crs('EPSG:4326')
# Criando um pandasdatagrame para armazenar todas as nossas linhas
df = pd.DataFrame(columns=['linha', 'parada'])

# Fazendo um loop para percorrer todas as linhas de onibus
for i in range(linestringLinhas.shape[0]):
    line = linestringLinhas.iloc[i]
    linestring = linestringLinhas.geometry.iloc[i]   

    # Criando listas para armazenar as paradas e dados dos ids da paradas encontradas
    paradas_encontradas = []
    data = []

    limite_proximidade = 0.0002

    # Iterar sobre os pontos de paradas e verificar se estão próximos da Linestring
    for idx, ponto_parada in paradas.iterrows():
        ponto = ponto_parada["geometry"]
        distancia = linestring.distance(ponto)
        if distancia <= limite_proximidade:
            paradas_encontradas.append(ponto_parada)

    # Criar um novo GeoDataFrame com as paradas encontradas
    gdf_paradas_encontradas = gpd.GeoDataFrame(paradas_encontradas, crs='EPSG:4326')

    # Plotar as paradas de ônibus no mapa com o Folium
    # m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

    for idx, ponto_parada in gdf_paradas_encontradas.iterrows():
        lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
        data.append([lat, lon, ponto_parada['parada']])
        # folium.Marker([lat, lon], popup=ponto_parada['parada']).add_to(m)
    df.loc[i] = [line.linha, data]
# Out:
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)

# %%
import os

if not os.path.exists('../databases/luiz_dataset'):
    os.makedirs('../databases/luiz_dataset')
df.to_csv('../databases/luiz_dataset/paradas_linestrings_ida.csv')

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium
import pandas as pd

# Filtrando a linestring apenas pelas linhas de onibus de ida
linestringLinhas = linhas[linhas['sentido']=='VOLTA']
linestringLinhas = linestringLinhas.to_crs('EPSG:4326')
# Criando um pandasdatagrame para armazenar todas as nossas linhas
df = pd.DataFrame(columns=['linha', 'parada'])

# Fazendo um loop para percorrer todas as linhas de onibus
for i in range(linestringLinhas.shape[0]):
    line = linestringLinhas.iloc[i]
    linestring = linestringLinhas.geometry.iloc[i]   

    # Criando listas para armazenar as paradas e dados dos ids da paradas encontradas
    paradas_encontradas = []
    data = []

    limite_proximidade = 0.0002

    # Iterar sobre os pontos de paradas e verificar se estão próximos da Linestring
    for idx, ponto_parada in paradas.iterrows():
        ponto = ponto_parada["geometry"]
        distancia = linestring.distance(ponto)
        if distancia <= limite_proximidade:
            paradas_encontradas.append(ponto_parada)

    # Criar um novo GeoDataFrame com as paradas encontradas
    gdf_paradas_encontradas = gpd.GeoDataFrame(paradas_encontradas, crs='EPSG:4326')

    # Plotar as paradas de ônibus no mapa com o Folium
    # m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

    for idx, ponto_parada in gdf_paradas_encontradas.iterrows():
        lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
        data.append([lat, lon, ponto_parada['parada']])
        # folium.Marker([lat, lon], popup=ponto_parada['parada']).add_to(m)
    df.loc[i] = [line.linha, data]
# Out:
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)

# %%
df
# Out:
#      linha                                             parada
# 0    0.018  [[-15.767293, -47.788723, 7557], [-15.77012499...
# 1    100.2  [[-15.858748568353112, -47.92771717852002, 250...
# 2    531.1  [[-15.638937404577504, -47.82260762728512, 491...
# 3    396.2  [[-15.866860500781998, -47.96679853983349, 605...
# 4    0.851  [[-15.866860500781998, -47.96679853983349, 605...
# ..     ...                                                ...
# 472  0.844  [[-15.880512000000007, -48.122922, 7626], [-15...
# 473  0.845  [[-15.898521115410318, -48.12156066472963, 411...
# 474  0.172  [[-15.866860500781998, -47.96679853983349, 605...
# 475  805.6  [[-15.86461088791683, -48.02439841365415, 5335...
# 476  506.2  [[-15.638590438131189, -47.82156276939281, 487...
#
# [477 rows x 2 columns]

# %%
print(df.linha[0]) # linha de ida da 0.018
df.parada[0] # Verificando os pontos de paradas com seus respectivos números.
# Out:
# 0.018
# [[-15.767293, -47.788723, '7557'],
#  [-15.770124999999993, -47.788733, '7558'],
#  [-15.76816299999999, -47.79217, '7559'],
#  [-15.76878769178167, -47.79181613649742, '6849'],
#  [-15.80215197439144, -47.85334236319928, '3274'],
#  [-15.810564155657119, -47.84685850621892, '2442'],
#  [-15.736023802288491, -47.9043530752539, '6287'],
#  [-15.803428845776875, -47.79425505968125, '2396'],
#  [-15.809442370814327, -47.80092191122717, '2395'],
#  [-15.803454253894726, -47.79461287922536, '2397'],
#  [-15.829392241144253, -47.81058449567555, '2389'],
#  [-15.831581136451492, -47.8129618471711, '2388'],
#  [-15.798766726003029, -47.87085223489018, '3270'],
#  [-15.799287300335465, -47.86919901400948, '3271'],
#  [-15.798242350178315, -47.872512648437414, '3269'],
#  [-15.800349949694871, -47.865823638647186, '3272'],
#  [-15.80140481164999, -47.86245692727506, '3273'],
#  [-15.817478071398625, -47.805750824839436, '2393'],
#  [-15.822977042333191, -47.805016085485335, '2391'],
#  [-15.820146118518355, -47.80504912316825, '2392'],
#  [-15.812808239882703, -47.804775773344375, '2394'],
#  [-15.826122070013904, -47.807021230860975, '2390'],
#  [-15.818830353576622, -47.83326930713607, '2443'],
#  [-15.764157999999997, -47.793713, '7560'],
#  [-15.763024000000007, -47.792896, '7561'],
#  [-15.762654999999999, -47.785836, '7555'],
#  [-15.764453999999999, -47.788622, '7556'],
#  [-15.763012000000002, -47.78935, '7562'],
#  [-15.763044999999995, -47.78651, '7563'],
#  [-15.762564999999999, -47.784828, '7564'],
#  [-15.762653033595509, -47.78497118582577, '6855'],
#  [-15.762575142626542, -47.78549231060707, '6856'],
#  [-15.7824250556501, -47.778203171611075, '2697'],
#  [-15.782404999999997, -47.778199, '7797'],
#  [-15.780086814616286, -47.77954208413691, '2698'],
#  [-15.831128089996014, -47.82619049996033, '2444'],
#  [-15.79501763943123, -47.78276348911926, '2350'],
#  [-15.785406445712793, -47.77728909161838, '2696'],
#  [-15.83530412611058, -47.821769542188825, '2386'],
#  [-15.835294075181668, -47.81849649042615, '2387'],
#  [-15.754208960654712, -47.89424438985205, '3528'],
#  [-15.75717373866217, -47.89329530076313, '3529'],
#  [-15.760465433818393, -47.89223559810704, '3530'],
#  [-15.750964679369993, -47.89528324932769, '3527'],
#  [-15.780964411486119, -47.887867366820046, '3537'],
#  [-15.777867601935073, -47.88808519169229, '3536'],
#  [-15.79595522497425, -47.88008167282463, '3268'],
#  [-15.763359943029167, -47.89131190194332, '3531'],
#  [-15.766656694428423, -47.8902569120232, '3532'],
#  [-15.76925722178799, -47.88955468811846, '3533'],
#  [-15.771805359502322, -47.888934384031636, '3534'],
#  [-15.7748788137897, -47.88843148773567, '3535'],
#  [-15.748031643828298, -47.89622512072298, '3526'],
#  [-15.78523008062385, -47.88797392390371, '3538'],
#  [-15.761097194970981, -47.78061837239957, '2707'],
#  [-15.738477194215498, -47.89929609836221, '3523'],
#  [-15.741813505314967, -47.898220834748756, '3524'],
#  [-15.744737354143842, -47.89728338606178, '3525']]

# %%
# Trabalhando com o dataframe criado
# Primeiro convertendo para array m*3
import numpy as np
a = np.array(df.parada[0])
a.shape
# Out:
# (58, 3)

# %%
import folium
from shapely.geometry import LineString

df1 = df[df['linha']=='0.813']


linha_exemplo = df1.iloc[0]

linha_coordinates = [(lat, lon) for lat, lon, _ in linha_exemplo['parada']]
paradas_coordinates = [(lat, lon) for lat, lon, _ in linha_exemplo['parada']]

linha_onibus = LineString(linha_coordinates)

m = folium.Map(location=[linha_coordinates[0][0], linha_coordinates[0][1]], zoom_start=13)

for lat, lon, popup_text in linha_exemplo['parada']:
    folium.Marker([lat, lon], popup=popup_text).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04e8a856477d50a49c2a41414bf58aea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04e8a856477d50a49c2a41414bf58aea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04e8a856477d50a49c2a41414bf58aea = L.map(
#                 &quot;map_04e8a856477d50a49c2a41414bf58aea&quot;,
#                 {
#                     center: [-15.912965715195082, -48.0991417564201],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a630f5df906e319b92ef88ce0728fd93 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_04e8a856477d50a49c2a41414bf58aea);
#
#
#             var marker_e82ad42c69fb9ae853808c2892d8de28 = L.marker(
#                 [-15.912965715195082, -48.0991417564201],
#                 {}
#             ).addTo(map_04e8a856477d50a49c2a41414bf58aea);
#
#
#         var popup_4f8a4707f9fd8a7148fbdbc709fc767c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e59d1e7ff6f8f16ab7cf52fd05dcfb4f = $(`&lt;div id=&quot;html_e59d1e7ff6f8f16ab7cf52fd05dcfb4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3882&lt;/div&gt;`)[0];
#                 popup_4f8a4707f9fd8a7148fbdbc709fc767c.setContent(html_e59d1e7ff6f8f16ab7cf52fd05dcfb4f);
#
#
#
#         marker_e82ad42c69fb9ae853808c2892d8de28.bindPopup(popup_4f8a4707f9fd8a7148fbdbc709fc767c)
#         ;
#
#
#
#
#             var marker_f22140eaf0bf5900d86b443f590c0d6f = L.marker(
#                 [-15.914350055552772, -48.10134574919791],
#                 {}
#             ).addTo(map_04e8a856477d50a49c2a41414bf58aea);
#
#
#         var popup_6ffcd854587b6da31398f3eaaa9afa47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99313199d9ec1733b4c1df9c266e9a26 = $(`&lt;div id=&quot;html_99313199d9ec1733b4c1df9c266e9a26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3883&lt;/div&gt;`)[0];
#                 popup_6ffcd854587b6da31398f3eaaa9afa47.setContent(html_99313199d9ec1733b4c1df9c266e9a26);
#
#
#
#         marker_f22140eaf0bf5900d86b443f590c0d6f.bindPopup(popup_6ffcd854587b6da31398f3eaaa9afa47)
#         ;
#
#
#
#
#             var marker_05a032194b1867920d7aac7e55c8fd8c = L.marker(
#                 [-15.918457625116746, -48.10193728176956],
#                 {}
#             ).addTo(map_04e8a856477d50a49c2a41414bf58aea);
#
#
#         var popup_5ba29543266a82dba48737030de521e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a90a34e6408afc92564e54f4ed37452c = $(`&lt;div id=&quot;html_a90a34e6408afc92564e54f4ed37452c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3884&lt;/div&gt;`)[0];
#                 popup_5ba29543266a82dba48737030de521e4.setContent(html_a90a34e6408afc92564e54f4ed37452c);
#
#
#
#         marker_05a032194b1867920d7aac7e55c8fd8c.bindPopup(popup_5ba29543266a82dba48737030de521e4)
#         ;
#
#
#
#
#             var marker_38f58b9058367bad48c387fcd62de3ef = L.marker(
#                 [-15.921831326303028, -48.103734162546544],
#                 {}
#             ).addTo(map_04e8a856477d50a49c2a41414bf58aea);
#
#
#         var popup_5bb7cd283daf92139b00debc1e9776c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a1771759abbe73021f6d3082cb015e7 = $(`&lt;div id=&quot;html_0a1771759abbe73021f6d3082cb015e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3885&lt;/div&gt;`)[0];
#                 popup_5bb7cd283daf92139b00debc1e9776c7.setContent(html_0a1771759abbe73021f6d3082cb015e7);
#
#
#
#         marker_38f58b9058367bad48c387fcd62de3ef.bindPopup(popup_5bb7cd283daf92139b00debc1e9776c7)
#         ;
#
#
#
#
#             var marker_0e4c2148b6689cd5eda0283567058576 = L.marker(
#                 [-15.923482770153871, -48.104634244060826],
#                 {}
#             ).addTo(map_04e8a856477d50a49c2a41414bf58aea);
#
#
#         var popup_94fa7e778213cfdb45639e54372e4af5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_301cc658d1e717cbaf181ddf4439a25b = $(`&lt;div id=&quot;html_301cc658d1e717cbaf181ddf4439a25b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3886&lt;/div&gt;`)[0];
#                 popup_94fa7e778213cfdb45639e54372e4af5.setContent(html_301cc658d1e717cbaf181ddf4439a25b);
#
#
#
#         marker_0e4c2148b6689cd5eda0283567058576.bindPopup(popup_94fa7e778213cfdb45639e54372e4af5)
#         ;
#
#
#
#
#             var marker_4dde57afc5db845e356ead3a894679a8

# %%
import os

if not os.path.exists('../databases/luiz_dataset'):
    os.makedirs('../databases/luiz_dataset')
df.to_csv('../databases/luiz_dataset/paradas_linestrings_volta.csv')

# %% [markdown]
# ### Como ler o arquivo das paradas corretamente no python
#
# Para evitar o erro do tipo de dado das linhas serem strings, é necessário passar para o atributo
# 'converters' = {'NOME DA COLUNA': pd.eval}
# ```python
# dt = pd.read_csv("../databases/luiz_dataset/paradas_linestrings.csv", converters={'parada': pd.eval})
# ```
