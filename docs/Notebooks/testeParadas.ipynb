# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as cx
from shapely.geometry import box, Point, Polygon, MultiPolygon
from shapely.wkt import loads

# %%
# lendo o arquivo .shp
caminho_shp = '../databases/paradas/paradas.shp'
df = gpd.read_file(caminho_shp)

# %%
# pegando algumas informações
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5457 entries, 0 to 5456
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   parada      5457 non-null   object
#  1   descricao   5456 non-null   object
#  2   situacao    5457 non-null   object
#  3   estrutura_  4948 non-null   object
#  4   tipo        5455 non-null   object
#  5   geometry    5457 non-null   geometry
# dtypes: geometry(1), object(5)
# memory usage: 255.9+ KB

# %%
# O que temos na coluna 'geometry' ?
df['geometry']
# Out:
# 0       POINT (203628.051 8238910.255)
# 1       POINT (203626.569 8238879.548)
# 2       POINT (203515.071 8238613.416)
# 3       POINT (203481.047 8238551.784)
# 4       POINT (203579.703 8239213.734)
#                      ...
# 5452    POINT (167354.394 8264495.757)
# 5453    POINT (167311.355 8264500.454)
# 5454    POINT (163265.979 8265332.396)
# 5455    POINT (162912.871 8269061.030)
# 5456    POINT (163217.911 8264159.565)
# Name: geometry, Length: 5457, dtype: geometry

# %%
# Qual sistemas estamos?
# acessando o atributo crs
df.crs
# Out:
# <Projected CRS: EPSG:31983>
# Name: SIRGAS 2000 / UTM zone 23S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Brazil - between 48°W and 42°W, northern and southern hemispheres, onshore and offshore.
# - bounds: (-48.0, -33.5, -42.0, 5.13)
# Coordinate Operation:
# - name: UTM zone 23S
# - method: Transverse Mercator
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# O folium trabalha no sistema WGS 84(EPSG:4326), o correto é converter para esse formato
df = df.to_crs('EPSG:4326')

# %%
# Agora conseguimos plotar

# Pegando uma cordenada pelo indice
x = df.geometry.x.iloc[0] # longitude
y = df.geometry.y.iloc[0] # latidute
print(f'Coordenada x: {x}\nCoordena y: {y}')
# Out:
# Coordenada x: -47.76791017881488
# Coordena y: -15.911319542624627

# %%
import folium

# Criar um mapa Folium centrado nas coordenadas do ponto selecionado
mapa = folium.Map(location=[y, x], zoom_start=12)

# Adicionar um marcador para o ponto no mapa
folium.Marker(location=[y, x]).add_to(mapa)

# Exibir o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2cfdc3f72551669359d15633a82bbc2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2cfdc3f72551669359d15633a82bbc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2cfdc3f72551669359d15633a82bbc2 = L.map(
#                 &quot;map_a2cfdc3f72551669359d15633a82bbc2&quot;,
#                 {
#                     center: [-15.911319542624627, -47.76791017881488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_831390f367a5a8c4b34bcecb71955f60 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a2cfdc3f72551669359d15633a82bbc2);
#
#
#             var marker_cfc07e37335065d33c912fa5d9117ea8 = L.marker(
#                 [-15.911319542624627, -47.76791017881488],
#                 {}
#             ).addTo(map_a2cfdc3f72551669359d15633a82bbc2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# verificando se faz sentido o plot
df['descricao'].iloc[0]
# Out:
# 'Avenida Morro da Cruz'

# %%
# Lendo o arquivo das linhas
file = '../databases/linhas/Linhas.shp'
linhas = gpd.read_file(file)
linhas.head(5)
linhas.linha.shape[0]
# Out:
# 1308

# %%
linestringRecanto = linhas[linhas['linha']=='0.813']
linestringRecantoIda = linestringRecanto.iloc[1] # ida
linestringRecantoVolta = linestringRecanto.iloc[0] # volta

# %%
import folium
from shapely.geometry import LineString

# Criar o objeto Linestring
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')

# Criar um mapa inicial
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

# Obter o objeto LineString a partir da coluna "geometry" do DataFrame
linestring1 = linestringRecanto.geometry.iloc[1] # Ida
linestring2 = linestringRecanto.geometry.iloc[0] # Volta

# Converter as coordenadas do Linestring para o formato que o Folium espera (latitude, longitude)
lat_lon_coordsIda = [(lat1, lon1) for lon1, lat1 in linestring1.coords]
lat_lon_coordsVolta = [(lat2, lon2) for lon2, lat2 in linestring2.coords]


# Adicionar o Linestring ao mapa como uma polilinha (linha poligonal)

# Plotando a ida
folium.PolyLine(locations=lat_lon_coordsIda, color='blue', tooltip=linestringRecanto['linha'].iloc[1]+ ' ' + linestringRecanto['sentido'].iloc[1]).add_to(m)

# Plotando a volta
folium.PolyLine(locations=lat_lon_coordsVolta, color='red', tooltip=linestringRecanto['linha'].iloc[0]+ ' ' + linestringRecanto['sentido'].iloc[0]).add_to(m)

# Mostrar o mapa
m.save('mapaLinestring.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01b4a9153b6591653a970e6531266a5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01b4a9153b6591653a970e6531266a5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01b4a9153b6591653a970e6531266a5e = L.map(
#                 &quot;map_01b4a9153b6591653a970e6531266a5e&quot;,
#                 {
#                     center: [-15.7605, -47.78134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fa02a18e00fc9c658911fb295ac66e8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01b4a9153b6591653a970e6531266a5e);
#
#
#             var poly_line_e104faf1659de60fe9d0cfb1a1d9a7e4 = L.polyline(
#                 [[-15.933102266916315, -48.10891754199306], [-15.933185998136672, -48.108807991238685], [-15.93340999523403, -48.108525495088145], [-15.933419523786512, -48.10849607013923], [-15.933419959958936, -48.10846583300539], [-15.933400571090756, -48.10841243949764], [-15.933305764283789, -48.108312854282865], [-15.933273562383947, -48.10830244488579], [-15.933243403196407, -48.10829693958246], [-15.933220235717016, -48.10830263140659], [-15.93319534110125, -48.108315353512296], [-15.932700948146334, -48.10895831300553], [-15.93244584156172, -48.10928197251519], [-15.932424904573713, -48.10928472361605], [-15.93240834520544, -48.10928312425452], [-15.932380701672058, -48.10927228097145], [-15.932011948441897, -48.10873397427042], [-15.9319625077659, -48.1087127140331], [-15.93191012725656, -48.108714931329196], [-15.931868362720541, -48.10872504111831], [-15.931834666028479, -48.1087639420912], [-15.931817167792971, -48.108823842662865], [-15.93224759865376, -48.109460764766446], [-15.932321336402978, -48.10959571923842], [-15.932344136311603, -48.10968349132112], [-15.932367098872463, -48.10980940054195], [-15.932362568692431, -48.10994307490539], [-15.932332517852501, -48.11008778122817], [-15.932263448418889, -48.11023255807511], [-15.93209405341763, -48.11047996059222], [-15.931919835284383, -48.11070107721031], [-15.93164789365474, -48.11106270696772], [-15.931610964986419, -48.11109401754556], [-15.931574144423534, -48.111099498503286], [-15.931544642856275, -48.11110475627459], [-15.931483116669263, -48.11109859898729], [-15.931430758331183, -48.11109995995848], [-15.931371718561225, -48.11111233911027], [-15.931314214428127, -48.11108658559446], [-15.931269858707546, -48.11105095367196], [-15.930189570128569, -48.110025346991186], [-15.929577608801964, -48.10944196575682], [-15.928258037828765, -48.10818838831729], [-15.927937294253818, -48.10788303427563], [-15.927807778842629, -48.10776257301313], [-15.927210362084208, -48.10719977473577], [-15.926851237016852, -48.106850148913], [-15.926316459959788, -48.10637012890984], [-15.926169384872782, -48.10624063970011], [-15.925699120415898, -48.10584314095591], [-15.92525405323611, -48.10549937884536], [-15.924633154958842, -48.10503975958355], [-15.92395940611415, -48.1045912156602], [-15.923597558362033, -48.104362528563165], [-15.923343469062997, -48.104214801694184], [-15.92323780194924, -48.10414664355253], [-15.92319567549768, -48.10409155944784], [-15.923160069885034, -48.104035231519724], [-15.923109431305207, -48.103939021310445], [-15.92307430063913, -48.103872283901616], [-15.923025215874963, -48.10380365184531], [-15.92297204641075, -48.10374772603555], [-15.922885035416126, -48.10368950153665], [-15.922772894873813, -48.103638245467074], [-15.922690773798758, -48.10361754051622], [-15.922600893039867, -48.103606900456164], [-15.92250622087745, -48.10361794380703], [-15.922447029236828, -48.10362809402743], [-15.922376056345888, -48.10363439553978], [-15.92231755238569, -48.10363282412056], [-15.922270905887581, -48.10362068217038], [-15.922191459484145, -48.10358317013326], [-15.92137248006535, -48.10314920666675], [-15.920771956285819, -48.102831171896646], [-15.920291771589174, -48.1025784965517], [-15.919486956621927, -48.1021541685875], [-15.918420606179355, -48.10160217223159], [-15.918236877854712, -48.10149048016219], [-15.918079902974803, -48.10139832132596], [-15.91799305090816, -48.10132981466096], [-15.917593551639234, -48.10102831954673], [-15.91740140651629, -48.1008687847479], [-15.91727878235172, -48.100758704211934], [-15.91701458934576, -48.10049927468045], [-15.916837677258178, -48.10032048571828], [-15.916482445936925, -48.099970279520946], [-15.916257154646464, -48.099718841476964], [-15.915045130008883, -48.098351814272284], [-15.91492382183887, -48.098217899751674], [-15.913771142545345, -48.09690623443199], [-15.91356507143006, -48.096674586537624], [-15.913440937405515, -48.096533574419475], [-15.913153510848991, -48.0962160052 ...

# %%
# Verificando paradas proximas a linestring

paradas = gpd.read_file("../databases/paradas/paradas.shp")
paradas.tail(5)
# Out:
#      parada                                          descricao situacao  \
# 5452   1163  NUCLEO RURAL RODEADOR - LADO OPOSTO ESCOLA ROD...    ATIVA
# 5453   1164  NUCLEO RURAL RODEADOR - EM FRENTE ESCOLA RODEA...    ATIVA
# 5454   1166  ANTES DA ENTRADA PARA A DF 445 NORTE - KM 7 DF...    ATIVA
# 5455   1159  LADO OPOSTO A ENTRADA DA RADIOBRAS E DF 220 DF...    ATIVA
# 5456   6374  Km 07 - Gleba 02 - Chácara 116 - Chácara Beatr...    ATIVA
#
#                estrutura_      tipo                        geometry
# 5452  ACOSTAMENTO OU BAIA    Tipo C  POINT (167354.394 8264495.757)
# 5453  ACOSTAMENTO OU BAIA    Tipo C  POINT (167311.355 8264500.454)
# 5454        SEM ESTRUTURA    Tipo C  POINT (163265.979 8265332.396)
# 5455        SEM ESTRUTURA  Habitual  POINT (162912.871 8269061.030)
# 5456        SEM ESTRUTURA    Padrão  POINT (163217.911 8264159.565)

# %%
# convertendo para o sistema adequado
paradas = paradas.to_crs('EPSG:4326')
paradas
# Out:
#      parada                                          descricao    situacao  \
# 0      6710                              Avenida Morro da Cruz  DESATIVADA
# 1      6711                              Avenida Morro da Cruz  DESATIVADA
# 2      6712                              Avenida Morro da Cruz  DESATIVADA
# 3      6713                              Avenida Morro da Cruz  DESATIVADA
# 4      6827                                Residencial Vitoria  DESATIVADA
# ...     ...                                                ...         ...
# 5452   1163  NUCLEO RURAL RODEADOR - LADO OPOSTO ESCOLA ROD...       ATIVA
# 5453   1164  NUCLEO RURAL RODEADOR - EM FRENTE ESCOLA RODEA...       ATIVA
# 5454   1166  ANTES DA ENTRADA PARA A DF 445 NORTE - KM 7 DF...       ATIVA
# 5455   1159  LADO OPOSTO A ENTRADA DA RADIOBRAS E DF 220 DF...       ATIVA
# 5456   6374  Km 07 - Gleba 02 - Chácara 116 - Chácara Beatr...       ATIVA
#
#                estrutura_      tipo                     geometry
# 0           SEM ESTRUTURA  Habitual  POINT (-47.76791 -15.91132)
# 1           SEM ESTRUTURA  Habitual  POINT (-47.76793 -15.91160)
# 2           SEM ESTRUTURA  Habitual  POINT (-47.76900 -15.91399)
# 3           SEM ESTRUTURA  Habitual  POINT (-47.76933 -15.91454)
# 4           SEM ESTRUTURA  Habitual  POINT (-47.76832 -15.90857)
# ...                   ...       ...                          ...
# 5452  ACOSTAMENTO OU BAIA    Tipo C  POINT (-48.10282 -15.67575)
# 5453  ACOSTAMENTO OU BAIA    Tipo C  POINT (-48.10322 -15.67570)
# 5454        SEM ESTRUTURA    Tipo C  POINT (-48.14080 -15.66765)
# 5455        SEM ESTRUTURA  Habitual  POINT (-48.14358 -15.63395)
# 5456        SEM ESTRUTURA    Padrão  POINT (-48.14141 -15.67823)
#
# [5457 rows x 6 columns]

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium

# Criar o objeto Linestring
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')

# Obter o objeto LineString a partir da coluna "geometry" do DataFrame
linestring = linestringRecanto.geometry.iloc[0]

# Lista para armazenar as paradas encontradas
paradas_encontradas = []

# Conjunto para armazenar os números das paradas encontradas
numeros_paradas_encontradas = set()

# Função para aproximar as coordenadas para 2 casas decimais
def aproximar_coordenadas(coord):
    return round(coord, 2)

# Iterar sobre os pontos de paradas e verificar se estão contidos na Linestring
for idx, ponto_parada in paradas.iterrows():
    numero_parada = ponto_parada["parada"]
    ponto = ponto_parada["geometry"]
    ponto_aproximado = Point(aproximar_coordenadas(ponto.x), aproximar_coordenadas(ponto.y))
    linestring_aproximada = LineString([Point(aproximar_coordenadas(x), aproximar_coordenadas(y)) for x, y in linestring.coords])
    if linestring_aproximada.contains(ponto_aproximado) and numero_parada not in numeros_paradas_encontradas:
        paradas_encontradas.append(ponto_parada)
        numeros_paradas_encontradas.add(numero_parada)

# Criar um novo GeoDataFrame com as paradas encontradas
gdf_paradas_encontradas = gpd.GeoDataFrame(paradas_encontradas, crs='EPSG:4326')
display(gdf_paradas_encontradas)
# Plotar as paradas de ônibus no mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

for idx, ponto_parada in gdf_paradas_encontradas.iterrows():
    lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
    folium.Marker([lat, lon], popup=ponto_parada['descricao']).add_to(m)

# Mostrar o mapa com as paradas de ônibus
m.save('mapa_paradas_onibus.html')
# Out:
#      parada                                          descricao situacao  \
# 69     3517                               EQN 513/514 W3 NORTE    ATIVA
# 70     3473                               SQN 113 EIXO W NORTE    ATIVA
# 494    3955  ENTRADA PARA Q. 508 CNJUNTOS 2. 3 E 3 AV. MONJOLO    ATIVA
# 495    3946  LADO OPOSTO Q. 508 APOS ENTRADA DA RUA DO PARQ...    ATIVA
# 496    3947  QUADRA 308 ANTES DA ENTRADA QUADRA 309 AV. MON...    ATIVA
# ...     ...                                                ...      ...
# 5292   3291             EQS 106/107 - Cine Brasília Eixo W Sul    ATIVA
# 5293   3343             EQS 106/107 - Cine Brasília Eixo W Sul    ATIVA
# 5300   3383             EQS 106/107 - CINE BRASILIA EIXO W SUL    ATIVA
# 5353   4723      APOS O VIADUTO DE ACESSO AO LAGO NORTE BR-020    ATIVA
# 5354   4583                                APOS VIADUTO DF-007    ATIVA
#
#                estrutura_            tipo                     geometry
# 69    ACOSTAMENTO OU BAIA     Tradicional  POINT (-47.89601 -15.74749)
# 70    ACOSTAMENTO OU BAIA     Tradicional  POINT (-47.88979 -15.74707)
# 494         SEM ESTRUTURA          Tipo C  POINT (-48.09974 -15.92356)
# 495         SEM ESTRUTURA          Tipo C  POINT (-48.09950 -15.92256)
# 496         SEM ESTRUTURA          Tipo C  POINT (-48.10099 -15.92465)
# ...                   ...             ...                          ...
# 5292  ACOSTAMENTO OU BAIA          Cemusa  POINT (-47.89929 -15.81486)
# 5293  ACOSTAMENTO OU BAIA          Cemusa  POINT (-47.89912 -15.81473)
# 5300  ACOSTAMENTO OU BAIA  Fibra de Vidro  POINT (-47.89896 -15.81460)
# 5353        SEM ESTRUTURA          Tipo C  POINT (-47.89611 -15.72536)
# 5354  ACOSTAMENTO OU BAIA          Tipo C  POINT (-47.89579 -15.72520)
#
# [453 rows x 6 columns]

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium

# Criar o objeto Linestring
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')

# Obter o objeto LineString a partir da coluna "geometry" do DataFrame
linestring = linestringRecanto.geometry.iloc[0]

# Lista para armazenar as paradas encontradas
paradas_encontradas = []

# Conjunto para armazenar os números das paradas encontradas
numeros_paradas_encontradas = set()

# Função para aproximar as coordenadas para 2 casas decimais
def aproximar_coordenadas(coord):
    return round(coord, 2)

# Iterar sobre os pontos de paradas e verificar se estão contidos na Linestring
for idx, ponto_parada in paradas.iterrows():
    numero_parada = ponto_parada["parada"]
    ponto = ponto_parada["geometry"]
    ponto_aproximado = Point(aproximar_coordenadas(ponto.x), aproximar_coordenadas(ponto.y))
    linestring_aproximada = LineString([Point(aproximar_coordenadas(x), aproximar_coordenadas(y)) for x, y in linestring.coords])
    if linestring_aproximada.contains(ponto_aproximado) and numero_parada not in numeros_paradas_encontradas:
        # Encontrar o ponto mais próximo na Linestring
        ponto_mais_proximo = linestring.interpolate(linestring.project(ponto))
        paradas_encontradas.append(ponto_mais_proximo)
        numeros_paradas_encontradas.add(numero_parada)

# Criar um novo GeoDataFrame com os pontos mais próximos encontrados
gdf_pontos_proximos = gpd.GeoDataFrame(geometry=paradas_encontradas, crs='EPSG:4326')

# Plotar os pontos mais próximos no mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

# %%
for idx, ponto in gdf_pontos_proximos.iterrows():
    lat, lon = ponto["geometry"].y, ponto["geometry"].x
    folium.Marker([lat, lon], icon=folium.Icon(color='blue'), popup=ponto_parada['parada']).add_to(m)

# Mostrar o mapa com os pontos mais próximos
m.save('mapa_pontos_proximos.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22a321113256f510609ce135782d0751 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22a321113256f510609ce135782d0751&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22a321113256f510609ce135782d0751 = L.map(
#                 &quot;map_22a321113256f510609ce135782d0751&quot;,
#                 {
#                     center: [-15.7605, -47.78134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ca9e71e6cec6a8179dc9bd97452ec99 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_22a321113256f510609ce135782d0751);
#
#
#             var marker_6dcc149dfc004d1ead67f816ced41200 = L.marker(
#                 [-15.747577640347307, -47.89628900845128],
#                 {}
#             ).addTo(map_22a321113256f510609ce135782d0751);
#
#
#             var icon_3436f25cddd18873e8487a0354f2ce83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6dcc149dfc004d1ead67f816ced41200.setIcon(icon_3436f25cddd18873e8487a0354f2ce83);
#
#
#         var popup_b98fb7be4f2e40b4f4682821533c0692 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c6b07420344db043917c35ac4972fd9 = $(`&lt;div id=&quot;html_1c6b07420344db043917c35ac4972fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6374&lt;/div&gt;`)[0];
#                 popup_b98fb7be4f2e40b4f4682821533c0692.setContent(html_1c6b07420344db043917c35ac4972fd9);
#
#
#
#         marker_6dcc149dfc004d1ead67f816ced41200.bindPopup(popup_b98fb7be4f2e40b4f4682821533c0692)
#         ;
#
#
#
#
#             var marker_db4e1c1cf010907a88fc80af08278891 = L.marker(
#                 [-15.74902404604422, -47.895829745018396],
#                 {}
#             ).addTo(map_22a321113256f510609ce135782d0751);
#
#
#             var icon_60b0b48516b143123276f09979a78257 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db4e1c1cf010907a88fc80af08278891.setIcon(icon_60b0b48516b143123276f09979a78257);
#
#
#         var popup_6bddf3d1c2d4cf850d01c871b30a1958 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e330a86ee916d4a92dee7b5bfefade3b = $(`&lt;div id=&quot;html_e330a86ee916d4a92dee7b5bfefade3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6374&lt;/div&gt;`)[0];
#                 popup_6bddf3d1c2d4cf850d01c871b30a1958.setContent(html_e330a86ee916d4a92dee7b5bfefade3b);
#
#
#
#         marker_db4e1c1cf010907a88fc80af08278891.bindPopup(popup_6bddf3d1c2d4cf850d01c871b30a1958)
#         ;
#
#
#
#
#             var marker_8a7903bbebdac42924b8697fc7f1ca15 = L.marker(
#                 [-15.921594934868015, -48.10350572118808],
#                 {}
#             ).addTo(map_22a321113256f510609ce135782d0751);
#
#
#             var icon_ceacb741a5e5350536aa5d5b81218433 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a7903bbebdac42924b8697fc7f1ca15.setIcon(icon_ceacb741a5e5350536aa5d5b81218433);
#
#
#         var popup_b7b68396c086a544b11e1688b40c4aed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2437a17e51d2992b615c0ed9d558fc5b = $(`&lt;div id=&quot;html_2437a17e51d2992b615c0ed9d558fc5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6374&lt;/div&gt;`)[0];
#                 popup_b7b68396c086a544b11e1688b40c4aed.setContent(html_2437a17e51d2992b615c0ed9d558fc5b);
#
#
#
#         marker_8a7903bbebdac42924b8697fc7f1ca15.bindPopup(popup_b7b68396c086a544b11e1688b40c4aed)
#         ;
#
#
#
#
#             var marker_88200a088e84295834127d7b720a31a3 = L.marker(
#                 [-15.920713729356407, -48.10304789323885],
#                 {}
#             ).addTo(map_22a321113256f510609ce135782d0751);
#
#
#             var icon_2fdd4eb6c460c16e04346a893a5f7b90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &qu

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium

# Criar o objeto Linestring
linestringRecanto = linestringRecanto.to_crs('EPSG:4326')

# Obter o objeto LineString a partir da coluna "geometry" do DataFrame
linestring = linestringRecanto.geometry.iloc[0]

# Lista para armazenar as paradas encontradas
paradas_encontradas = []

# Função para aproximar as coordenadas para 2 casas decimais

#def aproximar_coordenadas(coord):
#    return round(coord, )

# Definir o limite de proximidade aceitável (em graus)
limite_proximidade = 0.0013

# Iterar sobre os pontos de paradas e verificar se estão próximos da Linestring
for idx, ponto_parada in paradas.iterrows():
    ponto = ponto_parada["geometry"]
    distancia = linestring.distance(ponto)
    if distancia <= limite_proximidade:
        paradas_encontradas.append(ponto_parada)

# Criar um novo GeoDataFrame com as paradas encontradas
gdf_paradas_encontradas = gpd.GeoDataFrame(paradas_encontradas, crs='EPSG:4326')
display(gdf_paradas_encontradas)
# Plotar as paradas de ônibus no mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

for idx, ponto_parada in gdf_paradas_encontradas.iterrows():
    lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
    folium.Marker([lat, lon], popup=ponto_parada['parada']).add_to(m)

# Mostrar o mapa com as paradas de ônibus
m.save('mapa_paradas_onibus.html')
m
# Out:
#      parada                                          descricao situacao  \
# 69     3517                               EQN 513/514 W3 NORTE    ATIVA
# 497    3882  QUADRA 111 - AO LADO DO CENTRO DE ENSINO AV. R...    ATIVA
# 498    3883  QUADRA 112  ANTES QUADRA POLIESPORTIVA AV. REC...    ATIVA
# 499    3884       QUADRA 113 - FRENTE DO CEF 113 AV. REC. EMAS    ATIVA
# 500    3885                 QUADRA 114 - LOTE 06 AV. REC. EMAS    ATIVA
# ...     ...                                                ...      ...
# 5249   3520              EM FRENTE JUSTICA DO TRABALHO LIGACAO    ATIVA
# 5255   3519                         EQN 515/516 - BRB W3 NORTE    ATIVA
# 5256   3524  SCLN  ENTREQUADA 715/716 - AO LADO BANDEIRA VE...    ATIVA
# 5269   3525  SCLN  ENTREQUADA 714/715 - ATACADAO DA LIMPEZA...    ATIVA
# 5271   3518                     EQN 514/515 - HYUNDAI W3 NORTE    ATIVA
#
#                estrutura_         tipo                     geometry
# 69    ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89601 -15.74749)
# 497         SEM ESTRUTURA       Padrão  POINT (-48.09914 -15.91297)
# 498         SEM ESTRUTURA       Tipo C  POINT (-48.10135 -15.91435)
# 499   ACOSTAMENTO OU BAIA       Tipo C  POINT (-48.10194 -15.91846)
# 500         SEM ESTRUTURA       Padrão  POINT (-48.10373 -15.92183)
# ...                   ...          ...                          ...
# 5249        SEM ESTRUTURA       Cemusa  POINT (-47.89838 -15.73702)
# 5255  ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89805 -15.74110)
# 5256  ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89822 -15.74181)
# 5269  ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89728 -15.74474)
# 5271  ACOSTAMENTO OU BAIA  Tradicional  POINT (-47.89692 -15.74462)
#
# [270 rows x 6 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2384b7c88743417ddcb63ee19068be98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2384b7c88743417ddcb63ee19068be98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2384b7c88743417ddcb63ee19068be98 = L.map(
#                 &quot;map_2384b7c88743417ddcb63ee19068be98&quot;,
#                 {
#                     center: [-15.7605, -47.78134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_529d2b6cc43c5caeeed3cec042c842d5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2384b7c88743417ddcb63ee19068be98);
#
#
#             var marker_216b35b86dd366fe71789d64eb09c2eb = L.marker(
#                 [-15.747487243955707, -47.89600866323914],
#                 {}
#             ).addTo(map_2384b7c88743417ddcb63ee19068be98);
#
#
#         var popup_a0644eaa202474587094e1c4bbfda188 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5aaac8e03255cd51f8f28d89d333c5f6 = $(`&lt;div id=&quot;html_5aaac8e03255cd51f8f28d89d333c5f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3517&lt;/div&gt;`)[0];
#                 popup_a0644eaa202474587094e1c4bbfda188.setContent(html_5aaac8e03255cd51f8f28d89d333c5f6);
#
#
#
#         marker_216b35b86dd366fe71789d64eb09c2eb.bindPopup(popup_a0644eaa202474587094e1c4bbfda188)
#         ;
#
#
#
#
#             var marker_308bb235e49bb7d24c57928e64a36694 = L.marker(
#                 [-15.912965715195082, -48.0991417564201],
#                 {}
#             ).addTo(map_2384b7c88743417ddcb63ee19068be98);
#
#
#         var popup_4530bd6bd51802e593952756237df794 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82290ad55e799c3328b286b71c4040c6 = $(`&lt;div id=&quot;html_82290ad55e799c3328b286b71c4040c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3882&lt;/div&gt;`)[0];
#                 popup_4530bd6bd51802e593952756237df794.setContent(html_82290ad55e799c3328b286b71c4040c6);
#
#
#
#         marker_308bb235e49bb7d24c57928e64a36694.bindPopup(popup_4530bd6bd51802e593952756237df794)
#         ;
#
#
#
#
#             var marker_43e060dddfef2266b95fad5acad0462b = L.marker(
#                 [-15.914350055552772, -48.10134574919791],
#                 {}
#             ).addTo(map_2384b7c88743417ddcb63ee19068be98);
#
#
#         var popup_849913311f9005aaf955f08bd8018850 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efcec8f605a3483a172fc269377a68d6 = $(`&lt;div id=&quot;html_efcec8f605a3483a172fc269377a68d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3883&lt;/div&gt;`)[0];
#                 popup_849913311f9005aaf955f08bd8018850.setContent(html_efcec8f605a3483a172fc269377a68d6);
#
#
#
#         marker_43e060dddfef2266b95fad5acad0462b.bindPopup(popup_849913311f9005aaf955f08bd8018850)
#         ;
#
#
#
#
#             var marker_ab431416af453f182aa3414dbba3b8ea = L.marker(
#                 [-15.918457625116746, -48.10193728176956],
#                 {}
#             ).addTo(map_2384b7c88743417ddcb63ee19068be98);
#
#
#         var popup_60ef21c8e359fa2fe1c53ddf4ecdda3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32eb52079e55cf69c661c95c181cd877 = $(`&lt;div id=&quot;html_32eb52079e55cf69c661c95c181cd877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3884&lt;/div&gt;`)[0];
#                 popup_60ef21c8e359fa2fe1c53ddf4ecdda3a.setContent(html_32eb52079e55cf69c661c95c181cd877);
#
#
#
#         marker_ab431416af453f182aa3414dbba3b8ea.bindPopup(popup_60ef21c8e359fa2fe1c53ddf4ecdda3a)
#         ;
#
#
#
#
#             var marker_7a091fc0c1eaee5fb85b3546c42da70a = L.marker(
#                 [-15.921831326303028, -48.103734162546544],
#                 {}
#             ).addTo(map_2384b7c88743417ddcb63ee19068be98);
#
#
#         var popup_367a7719a82a8708c6f5522adfa900a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfdd9cc704e17df8ec9d72529235c8a4 = $(`&lt;div id=&quot;html_dfdd9cc704e17df8ec9d72529235c8a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3885&lt;/div&gt;`)[0];
#                 popup_367a7719a82a8708c6f5522adfa900a0.setContent(html_dfdd9cc704e17df8ec9d72529235c8a4);
#
#
#
#         marker_7a091fc0c1eaee5fb85b3546c42da70a.bindPopup(popup_367a7719a82a8708c6f5522adfa900a0)
#         ;
#
#
#
#
#             var marker_34c2bac6a9ddd37492838688d6065669 = L.marker(

# %%
linestringLinhas = linhas[linhas['sentido']=='IDA']
for i in range(linestringLinhas.shape[0]):
     line = linestringLinhas.iloc[i]
     display(line.linha)
# Out:
# '0.018'
# '0.946'
# '0.373'
# '503.3'
# '531.1'
# '0.851'
# '330.1'
# '0.522'
# '519.3'
# '0.520'
# '932.4'
# '0.550'
# '0.853'
# '0.882'
# '807.4'
# '617.2'
# '920.4'
# '0.883'
# '156.7'
# '1001'
# '515.6'
# '506.4'
# '2205'
# '0.958'
# '0.555'
# '376.2'
# '759.1'
# '206.9'
# '504.5'
# '305.4'
# '0.305'
# '136.9'
# '300.1'
# '823.2'
# '0.181'
# '156.9'
# '0.101'
# '0.322'
# '0.175'
# '167.1'
# '0.370'
# '158.3'
# '348.1'
# '147.2'
# '807.8'
# '0.624'
# '0.382'
# '0.394'
# '557.1'
# '373.2'
# '761.1'
# '194.1'
# '501.2'
# '136.6'
# '0.871'
# '600.2'
# '519.1'
# '501.3'
# '322.1'
# '190.2'
# '844.2'
# '180.2'
# '396.3'
# '100.8'
# '413.2'
# '0.420'
# '0.421'
# '413.4'
# '136.7'
# '2306'
# '199.1'
# '340.1'
# '197.3'
# '611.1'
# '0.412'
# '0.403'
# '0.404'
# '0.930'
# '413.1'
# '0.503'
# '0.611'
# '3317'
# '100.9'
# '0.773'
# '0.884'
# '638.1'
# '0.819'
# '0.511'
# '616.3'
# '392.2'
# '813.2'
# '630.2'
# '501.7'
# '3311'
# '423.1'
# '0.527'
# '136.3'
# '181.4'
# '411.1'
# '0.913'
# '100.2'
# '808.1'
# '196.2'
# '170.1'
# '807.9'
# '0.911'
# '0.622'
# '0.346'
# '0.374'
# '374.2'
# '0.756'
# '0.526'
# '0.771'
# '0.878'
# '963.1'
# '0.850'
# '172.7'
# '0.640'
# '0.903'
# '0.513'
# '871.3'
# '206.3'
# '0.377'
# '0.617'
# '0.182'
# '643.1'
# '323.2'
# '154.3'
# '147.7'
# '382.1'
# '806.1'
# '616.4'
# '181.1'
# '400.2'
# '0.376'
# '376.3'
# '305.6'
# '910.1'
# '411.2'
# '0.764'
# '0.942'
# '376.1'
# '0.378'
# '0.808'
# '180.0'
# '160.1'
# '0.198'
# '0.314'
# '0.818'
# '0.806'
# '624.1'
# '0.317'
# '0.762'
# '0.375'
# '372.9'
# '0.918'
# '515.3'
# '0.834'
# '373.3'
# '0.199'
# '808.5'
# '540.1'
# '335.1'
# '0.258'
# '147.9'
# '0.215'
# '336.1'
# '147.4'
# '160.2'
# '533.1'
# '398.1'
# '0.821'
# '0.424'
# '600.3'
# '850.1'
# '182.2'
# '2303'
# '0.153'
# '336.2'
# '0.380'
# '386.1'
# '343.2'
# '504.4'
# '760.1'
# '825.1'
# '0.768'
# '0.205'
# '0.234'
# '0.841'
# '0.331'
# '0.162'
# '3312'
# '942.2'
# '604.3'
# '0.525'
# '0.330'
# '0.631'
# '0.962'
# '147.3'
# '616.6'
# '0.185'
# '100.4'
# '0.953'
# '367.8'
# '374.1'
# '640.1'
# '197.1'
# '0.147'
# '519.2'
# '0.554'
# '147.5'
# '0.910'
# '0.519'
# '0.194'
# '379.1'
# '2202'
# '630.1'
# '0.781'
# '0.255'
# '780.1'
# '0.881'
# '158.4'
# '389.1'
# '0.310'
# '640.2'
# '152.3'
# '188.1'
# '620.1'
# '132.3'
# '0.400'
# '0.906'
# '0.638'
# '805.7'
# '512.1'
# '0.300'
# '0.516'
# '3310'
# '0.340'
# '0.769'
# '2203'
# '306.5'
# '0.338'
# '0.216'
# '0.954'
# '0.405'
# '0.160'
# '334.4'
# '0.552'
# '0.324'
# '0.385'
# '600.8'
# '206.8'
# '0.763'
# '0.180'
# '602.1'
# '932.1'
# '616.5'
# '0.604'
# '0.605'
# '0.835'
# '384.1'
# '0.391'
# '0.616'
# '616.2'
# '306.2'
# '844.1'
# '604.1'
# '604.2'
# '764.2'
# '932.3'
# '0.517'
# '0.760'
# '605.1'
# '515.4'
# '346.1'
# '550.1'
# '0.907'
# '380.4'
# '615.1'
# '0.558'
# '811.1'
# '902.2'
# '932.2'
# '0.392'
# '173.1'
# '0.366'
# '0.334'
# '0.170'
# '506.0'
# '0.627'
# '2206'
# '0.186'
# '180.1'
# '0.167'
# '0.301'
# '600.7'
# '255.2'
# '170.6'
# '100.6'
# '517.2'
# '396.2'
# '158.6'
# '0.224'
# '0.518'
# '648.1'
# '087.5'
# '0.275'
# '207.2'
# '874.4'
# '0.349'
# '180.3'
# '504.1'
# '2309'
# '0.531'
# '0.556'
# '366.5'
# '0.641'
# '383.3'
# '616.7'
# '340.3'
# '380.2'
# '0.312'
# '0.602'
# '343.6'
# '865.1'
# '509.1'
# '2208'
# '0.960'
# '0.092'
# '0.601'
# '942.1'
# '625.1'
# '379.2'
# '190.4'
# '394.1'
# '0.197'
# '0.816'
# '066.1'
# '163.1'
# '206.2'
# '194.2'
# '2212'
# '0.195'
# '2310'
# '206.5'
# '0.348'
# '0.811'
# '338.1'
# '0.411'
# '0.339'
# '870.1'
# '197.6'
# '158.7'
# '260.3'
# '616.1'
# '0.345'
# '322.2'
# '0.273'
# '0.643'
# '0.379'
# '806.8'
# '642.1'
# '397.2'
# '0.914'
# '3211'
# '0.196'
# '0.920'
# '0.176'
# '313.2'
# '0.761'
# '0.813'
# '391.3'
# '0.600'
# '0.620'
# '603.1'
# '147.6'
# '2307'
# '845.2'
# '101.8'
# '0.603'
# '805.3'
# '160.3'
# '0.780'
# '2301'
# '2201'
# '156.8'
# '823.1'
# '383.1'
# '0.504'
# '870.7'
# '511.4'
# '158.2'
# '3313'
# '0.648'
# '0.129'
# '324.1'
# '0.825'
# '0.902'
# '600.4'
# '760.2'
# '366.7'
# '197.5'
# '531.3'
# '156.1'
# '306.1'
# '154.2'
# '205.1'
# '0.372'
# '0.515'
# '0.810'
# '0.822'
# '398.3'
# '2302'
# '0.253'
# '642.2'
# '0.383'
# '505.4'
# '0.765'
# '0.642'
# '0.886'
# '818.1'
# '0.759'
# '813.1'
# '761.2'
# '067.1'
# '197.7'
# '0.965'
# '101.1'
# '2308'
# '872.3'
# '0.158'
# '0.171'
# '0.397'
# '0.343'
# '642.3'
# '0.371'
# '380.3'
# '366.1'
# '207.3'
# '0.132'
# '157.9'
# '600.5'
# '394.4'
# '0.509'
# '670.3'
# '158.5'
# '372.2'
# '0.966'
# '870.9'
# '0.932'
# '0.306'
# '0.225'
# '807.1'
# '501.1'
# '0.845'
# '2210'
# '0.159'
# '0.670'
# '0.809'
# '157.5'
# '0.521'
# '0.876'
# '844.3'
# '0.900'
# '310.1'
# '180.6'
# '180.5'
# '501.5'
# '0.512'
# '337.1'
# '600.6'
# '0.399'
# '0.501'
# '0.336'
# '206.1'
# '385.1'
# '0.823'
# '401.1'
# '637.2'
# '0.347'
# '100.3'
# '0.873'
# '0.844'
# '0.172'
# '805.6'
# '506.2'
# '813.3'

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import folium
import pandas as pd

# Filtrando a linestring apenas pelas linhas de onibus de ida
linestringLinhas = linhas[linhas['sentido']=='IDA']
linestringLinhas = linestringLinhas.to_crs('EPSG:4326')
# Criando um pandasdatagrame para armazenar todas as nossas linhas
df = pd.DataFrame(columns=['linha', 'ponto(lat,lon)/id_da_parada'])

# Fazendo um loop para percorrer todas as linhas de onibus
for i in range(linestringLinhas.shape[0]):
    line = linestringLinhas.iloc[i]
    linestring = linestringLinhas.geometry.iloc[i]   

    # Criando listas para armazenar as paradas e dados dos ids da paradas encontradas
    paradas_encontradas = []
    data = []

    limite_proximidade = 0.0013

    # Iterar sobre os pontos de paradas e verificar se estão próximos da Linestring
    for idx, ponto_parada in paradas.iterrows():
        ponto = ponto_parada["geometry"]
        distancia = linestring.distance(ponto)
        if distancia <= limite_proximidade:
            paradas_encontradas.append(ponto_parada)

    # Criar um novo GeoDataFrame com as paradas encontradas
    gdf_paradas_encontradas = gpd.GeoDataFrame(paradas_encontradas, crs='EPSG:4326')

    # Plotar as paradas de ônibus no mapa com o Folium
    # m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

    for idx, ponto_parada in gdf_paradas_encontradas.iterrows():
        lat, lon = ponto_parada["geometry"].y, ponto_parada["geometry"].x
        data.append([lat, lon, ponto_parada['parada']])
        # folium.Marker([lat, lon], popup=ponto_parada['parada']).add_to(m)
    df.loc[i] = [line.linha, data]
# Out:
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import pandas as pd

# Filtrando a linestring apenas pelas linhas de onibus de ida
linestringLinhas = linhas[linhas['sentido'] == 'IDA']
linestringLinhas = linestringLinhas.to_crs('EPSG:4326')

# Criando um DataFrame para armazenar todas as nossas linhas
df = pd.DataFrame(columns=['linha', 'paradas'])

# Definir o limite de proximidade aceitável (em graus)
limite_proximidade = 0.0013

# Fazendo um loop para percorrer todas as linhas de ônibus
for i in range(linestringLinhas.shape[0]):
    line = linestringLinhas.iloc[i]
    linestring = linestringLinhas.geometry.iloc[i]

    # Lista para armazenar as paradas encontradas
    paradas_encontradas = []

    # Iterar sobre os pontos de paradas e verificar se estão próximos da Linestring
    for idx, ponto_parada in paradas.iterrows():
        ponto = ponto_parada["geometry"]
        distancia = linestring.distance(ponto)
        if distancia <= limite_proximidade:
            paradas_encontradas.append(ponto_parada["geometry"])

    # Criar um novo GeoDataFrame com as paradas encontradas
    gdf_paradas_encontradas = gpd.GeoDataFrame(geometry=paradas_encontradas, crs='EPSG:4326')

    # Adicionar informações ao DataFrame principal
    df.loc[i] = [line.linha, gdf_paradas_encontradas]

# Exibir o DataFrame principal
print(df)
# Out:
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /home/luiz/.pyenv/versions/3.11.3/envs/dev/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
#      linha                                            paradas
# 0    0.018                          geometry
# 0    POINT (-...
# 1    0.946                          geometry
# 0    POINT (-...
# 2    0.373                          geometry
# 0    POINT (-...
# 3    503.3                          geometry
# 0    POINT (-...
# 4    531.1                         geometry
# 0   POINT (-47...
# ..     ...                                                ...
# 482  0.844                          geometry
# 0    POINT (-...
# 483  0.172                          geometry
# 0    POINT (-...
# 484  805.6                          geometry
# 0    POINT (-...
# 485  506.2                         geometry
# 0   POINT (-47...
# 486  813.3                          geometry
# 0    POINT (-...
#
# [487 rows x 2 columns]

# %%
import os

if not os.path.exists('../databases/luiz_dataset'):
    os.makedirs('../databases/luiz_dataset')
df.to_csv('../databases/luiz_dataset/paradas_linestrings.csv')

# %%
# Filtrar apenas a linha '813'
linha_813_2 = df[df['linha'] == '813.2']

# Criar um mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

# Iterar sobre as paradas da linha '813' e adicionar marcadores ao mapa
for idx, row in linha_813_2.iterrows():
    for ponto_parada in row['paradas'].geometry:
        lat, lon = ponto_parada.y, ponto_parada.x
        folium.Marker([lat, lon], popup=f"Linha: {row['linha']}").add_to(m)

# Mostrar o mapa com as paradas da linha '813'
m.save('mapa_linha_813.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab9fd195e6397718993e4c58b5047bcd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab9fd195e6397718993e4c58b5047bcd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab9fd195e6397718993e4c58b5047bcd = L.map(
#                 &quot;map_ab9fd195e6397718993e4c58b5047bcd&quot;,
#                 {
#                     center: [-15.7605, -47.78134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e0de298ead1acda192d4dbbc0da1a85 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab9fd195e6397718993e4c58b5047bcd);
#
#
#             var marker_2d6473c89132e21ec2cc0de892e6309a = L.marker(
#                 [-15.747487243955707, -47.89600866323914],
#                 {}
#             ).addTo(map_ab9fd195e6397718993e4c58b5047bcd);
#
#
#         var popup_1ad3d42cf2b0f2d0a18861a1c63bb383 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1543119c357c4182096396e2fae57df0 = $(`&lt;div id=&quot;html_1543119c357c4182096396e2fae57df0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Linha: 813.2&lt;/div&gt;`)[0];
#                 popup_1ad3d42cf2b0f2d0a18861a1c63bb383.setContent(html_1543119c357c4182096396e2fae57df0);
#
#
#
#         marker_2d6473c89132e21ec2cc0de892e6309a.bindPopup(popup_1ad3d42cf2b0f2d0a18861a1c63bb383)
#         ;
#
#
#
#
#             var marker_3d2eae55457c3d0f2a83b22ec9c71e71 = L.marker(
#                 [-15.86636414076346, -47.96304244645044],
#                 {}
#             ).addTo(map_ab9fd195e6397718993e4c58b5047bcd);
#
#
#         var popup_8578b16ca5c8e9fbfb0c28a4b869dda9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21ff2ee0c088bd0598e8bb925b44bcbd = $(`&lt;div id=&quot;html_21ff2ee0c088bd0598e8bb925b44bcbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Linha: 813.2&lt;/div&gt;`)[0];
#                 popup_8578b16ca5c8e9fbfb0c28a4b869dda9.setContent(html_21ff2ee0c088bd0598e8bb925b44bcbd);
#
#
#
#         marker_3d2eae55457c3d0f2a83b22ec9c71e71.bindPopup(popup_8578b16ca5c8e9fbfb0c28a4b869dda9)
#         ;
#
#
#
#
#             var marker_a5a307271094ef6ff7c2cd723d994b6a = L.marker(
#                 [-15.866094249254065, -47.96286501986289],
#                 {}
#             ).addTo(map_ab9fd195e6397718993e4c58b5047bcd);
#
#
#         var popup_e5ebe6e2d318e272e2aef460e084f090 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68b7038b9dd7b76efea45fc41abdc5d9 = $(`&lt;div id=&quot;html_68b7038b9dd7b76efea45fc41abdc5d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Linha: 813.2&lt;/div&gt;`)[0];
#                 popup_e5ebe6e2d318e272e2aef460e084f090.setContent(html_68b7038b9dd7b76efea45fc41abdc5d9);
#
#
#
#         marker_a5a307271094ef6ff7c2cd723d994b6a.bindPopup(popup_e5ebe6e2d318e272e2aef460e084f090)
#         ;
#
#
#
#
#             var marker_d0d2b071adbc7e06acdc5b7cc780ff98 = L.marker(
#                 [-15.866860500781998, -47.96679853983349],
#                 {}
#             ).addTo(map_ab9fd195e6397718993e4c58b5047bcd);
#
#
#         var popup_8d388de36711a24eb6b5e30d219f7625 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a68d4e60d8213029028ee20839d56d0 = $(`&lt;div id=&quot;html_5a68d4e60d8213029028ee20839d56d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Linha: 813.2&lt;/div&gt;`)[0];
#                 popup_8d388de36711a24eb6b5e30d219f7625.setContent(html_5a68d4e60d8213029028ee20839d56d0);
#
#
#
#         marker_d0d2b071adbc7e06acdc5b7cc780ff98.bindPopup(popup_8d388de36711a24eb6b5e30d219f7625)
#         ;
#
#
#
#
#             var marker_d03cf115d0afa0c60f38ae49579fd54e = L.marker(
#                 [-15.866555379423424, -47.96504713913905],
#                 {}
#             ).addTo(map_ab9fd195e6397718993e4c58b5047bcd);
#
#
#         var popup_f0ab5f019d8b23b28f50ff71a9b58b82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02144c2f350540999ae4e61080467fee = $(`&lt;div id=&quot;html_02144c2f350540999ae4e61080467fee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Linha: 813.2&lt;/div&gt;`)[0];
#                 popup_f0ab5f019d8b23b28f50ff71a9b58b82.setContent(html_02144c2f350540999ae4e61080467fee);
#
#
#
#         marker_d03cf115d0afa0c60f38ae49579fd54e.bindPopup(popup_f0ab5f019d8b23b28f50ff71a9b58b82)
#         ;
#
#
#
#
#             var marker_98ac0129001ba

# %%
# Filtrar apenas a linha '813'
linha_813 = df[df['linha'] == '813']

# Criar um mapa com o Folium
m = folium.Map(location=[-15.76050, -47.78134], zoom_start=10)

# Iterar sobre as paradas da linha '813' e adicionar marcadores ao mapa
for idx, row in linha_813.iterrows():
    for ponto_parada in row['paradas'].geometry:
        lat, lon = ponto_parada.y, ponto_parada.x
        folium.Marker([lat, lon], popup=f"Linha: {row['linha']}").add_to(m)

# Mostrar o mapa com as paradas da linha '813'
m.save('mapa_linha_813.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8911208010371c7617be625733d4ca55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8911208010371c7617be625733d4ca55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8911208010371c7617be625733d4ca55 = L.map(
#                 &quot;map_8911208010371c7617be625733d4ca55&quot;,
#                 {
#                     center: [-15.7605, -47.78134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc6e9051d7066523d6d16af6cbbe571c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8911208010371c7617be625733d4ca55);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
